# %% [markdown]
# Create a model using built-in library from Pytorch.
# This code closely follows nn_tutorial notebook.

# %%
import os
from google.colab import drive
drive.mount('/content/gdrive')
# !pwd
os.chdir('gdrive/My Drive/PyHack2019/')
# !pwd
# !ls

# %%
import csv, torch, math, os, pickle
from torch import nn
from torch import optim
import torch.nn.functional as F

global chroma_shape, epochs, train_bs, validate_bs, lr, n_class

if torch.cuda.is_available():
  device = 'cuda'
else:
  device = 'cpu'
  
print(device)
# Out:
# cuda

# %%
## read attr and tar in .pkl files
## Param: ratio = training size to the sample size. 
##         E.g. 0.7 means using 70% of the samples as training 
##              sample and the rest as validation sample. 
## Return: (1) a list of padded attr arrays
##         (2) a list of paddrd tar arrays
def read_data(ratio):
    
    assert (ratio > 0 and ratio < 1), 'Invalid ratio'
    
    
    att_file = open(r'mfcc_noise_attr.pkl', 'rb')
    x_train = pickle.load(att_file)  
    att_file.close()
    
    tar_file = open(r'mfcc_noise_tar.pkl', 'rb')
    str_y_train = pickle.load(tar_file)
    tar_file.close()
    
    y = []
    class_map = ['c', 'ch', 'q', 's', 'sh', 'x', 'z', 'zh']
    for s in str_y_train:
      if s in class_map:
        y.append(class_map.index(s))
      else:
        y.append(8)
    #print(y)
    y = torch.tensor(y)
    #y = torch.tensor([0 if s == 's' else (1 if s == 'x' else 2) for s in str_y_train])
    #y = torch.tensor([class_map.index(s) if s in class_map else 9 for s in str_y_train])
    assert (len(x_train) == len(y)), 'Unequal sample lengths'
    
    #print([(x,s) for x, s in zip(str_y_train, y_train)])
    
    ## need .float so that it has the same type as weights in the model
    #return torch.tensor(x_train).float(), y_train
    #print(x_train[0].shape, x_train[1].shape, x_train[2].shape)
    #print(x_train[len(x_train)-2].shape)
    x = torch.tensor(x_train).float() 
    divider = int(len(y)*ratio)
    
    
    x_train = x[:divider, :, :]
    y_train = y[:divider]
    
    print(x_train.shape, x.shape)

    x_validate = x[divider:, :, :]
    y_validate = y[divider:]

    assert (x_train.shape[0] + x_validate.shape[0] == len(y_train) + len(y_validate)), 'Lengths do not add up'

    return x_train, y_train, x_validate, y_validate

# %%
x_train, y_train, x_validate, y_validate = read_data(0.7)

x_train = x_train.to(device)
y_train = y_train.to(device)
x_validate = x_validate.to(device)
y_validate = y_validate.to(device)

print (x_train.device)
# Out:
# torch.Size([11709, 13, 239]) torch.Size([16728, 13, 239])
# cuda:0

# %%
device
# Out:
# 'cuda'

# %%
x_train.shape
# Out:
# torch.Size([11709, 13, 239])

# %%
def accuracy(out, yb):
    ##get the index with the max
    preds = torch.argmax(out, dim = 1)
    return (preds == yb).float().mean()

# %%
## Get the shape of a padded instance for model construction
chroma_shape = x_train[0].shape

#epochs = 50
#train_bs = 20
#validate_bs = train_bs*2
n_train = x_train.shape[0]
n_validate = x_validate.shape[0]
n_class = 9

loss_func = F.cross_entropy

# %% [markdown]
# Since there are three classes, we set D_out to 3. n is total number of instances and c is the number of attributes in each instance. We use a loss function from torch.nn.functional.

# %%
## 13*239
class SoundRecognition_CNN(nn.Module):
  
    def __init__(self, dropout_rate):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=0)
        self.conv2 = nn.Conv2d(16, 16, kernel_size=3, stride=1, padding=0)
        self.conv3 = nn.Conv2d(16, 16, kernel_size=3, stride=1, padding=0)
        
        self.dropout = nn.Dropout(p = dropout_rate)
        
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = torch.nn.Linear(16*3*116, n_class)

    def forward(self, xb):
        #print(type(xb), len(xb))
        
        ## input of size (bs, 1, 12, 60)
        xb = xb.view(-1, 1, chroma_shape[0], chroma_shape[1])
        #print('xb shape', xb.shape)
        
        ## (bs, 1, 12, 60) >> (bs, 16, 10, 58)
        xb = self.dropout(F.relu(self.conv1(xb)))
        #print('---xb shape2', xb.shape)
        
        ## (bs, 16, 10, 58) >> (bs, 16, 8, 56)
        xb = self.dropout(F.relu(self.conv2(xb)))
        #print('---xb shape3', xb.shape)
        
        ## (bs, 16, 8, 56) >> (bs, 16, 6, 54)
        xb = self.dropout(F.relu(self.conv3(xb)))
        #print('---xb shape4', xb.shape)
        
        ## (bs, 16, 6, 54) >> (bs, 16, 3, 27)
        xb = self.pool(xb)
        #print('---xb shape5', xb.shape)
        #print('sh', xb.shape)
        ## reshape for fully connected
        #xb = xb.view(-1, 16*3*27)
        xb = xb.view(-1, 16*3*116)
        
        ## (bs, 16*3*27) >> (bs, 3)
        xb = self.fc1(xb)
        #print('---xb shape6', xb.shape)
        #print('=====', xb.shape)
        return xb.view(-1, xb.size(1))

## Get the model and optim object that will be used to update model parameters
def get_model(dropout_rate, weight_decay, lr):
    model = SoundRecognition_CNN(dropout_rate)
    return model, optim.Adam(model.parameters(), weight_decay = weight_decay, lr = lr)

# %%
def validate(trained_model, validate_bs, n_validate):
    trained_model.eval()
    loss = []
    acc = []
    with torch.no_grad():

        for i in range((n_validate - 1) // validate_bs + 1):
            start_i = i * validate_bs
            end_i = start_i + validate_bs
            #print(xb.shape)
            xb = x_validate[start_i:end_i, :, :]
            yb = y_validate[start_i:end_i]
            pred = trained_model(xb)
            loss.append(loss_func(pred, yb))
            acc.append(accuracy(pred, yb))

        #print(loss)
        valid_loss = sum(loss)
    return valid_loss, sum(acc)/len(acc)

# %%
def fit(epochs = 100, 
        train_bs = 10, 
        n_train = n_train, 
        validate_bs = 20, 
        n_validate = n_validate,
        dropout_rate = 0.5, 
        weight_decay = 1e-6, 
        lr = 1e-4,
        tolerance = 0.05):
  
  
  model, opt = get_model(dropout_rate = dropout_rate, weight_decay = weight_decay, lr = lr)
  model.to(device)
  
  ## to save training progress
  text_file = ''
  prev_small_vl = 10000000
  for epoch in range(epochs):

      #print('Training')
      model.train()
      for i in range((n_train - 1) // train_bs + 1):

          start_i = i * train_bs
          end_i = start_i + train_bs
          xb = x_train[start_i:end_i, :, :]
          yb = y_train[start_i:end_i]
          pred = model(xb)
          #print('pred: ', pred, ' | yb: ', yb)
          loss = loss_func(pred, yb)

          loss.backward()
          opt.step()
          opt.zero_grad()

      valid_loss, acc = validate(model, validate_bs, n_validate)
      
      ##early stop
      if valid_loss < prev_small_vl:
        prev_small_vl = valid_loss
      elif valid_loss > prev_small_vl*(1+tolerance):
        print('Epoch: ', epoch, ' == Early stop due to an increase in validation loss')
        break
      

      if (epoch + 1)% 10 == 0:
          print('Epoch: ', epoch + 1, ' | Loss: ', valid_loss, ' | Accuracy: ', acc)
          text_file = text_file + 'Epoch: '+ str(epoch + 1) + ' | Loss: ' + str(valid_loss) + ' | Accuracy: ' + str(acc) + '\n'
  text_file = str(model) + '\n\n' + text_file
  print('Train Finished')
  return model, text_file

# %%
# m, t = fit(epochs = 20, 
#     train_bs = 10, 
#     n_train = n_train, 
#     validate_bs = 20, 
#     n_validate = n_validate,
#     dropout_rate = 0.5, 
#     weight_decay = 1e-6, 
#     lr = 1e-4)

# %%
def getName(epochs, dropout_rate, weight_decay, lr):
  
  name = 'mfcc_m_' + str(epochs) + '_dr' + str(dropout_rate) + '_wc' + str(weight_decay) + '_lr' + str(try_lr)
  return name +'.pt', name +'.txt'

# %%
m, t_file = fit(epochs = 500, 
                train_bs = 100, 
                n_train = n_train, 
                validate_bs = 200, 
                n_validate = n_validate,
                dropout_rate = 0.5, 
                weight_decay = 0.01, 
                lr = 1e-5,
                tolerance = 0.05)
# Out:
# Epoch:  10  | Loss:  tensor(47.9266, device='cuda:0')  | Accuracy:  tensor(0.6749, device='cuda:0')
# Epoch:  10  == Early stop due to an increase in validation loss
# Train Finished

# %%
#torch.save(m, model_dir + m_save_path)

torch.save(m, 'model/nine_early_stop_mfcc_noise_trained.pt')
file = open('model/nine_early_stop_mfcc_noise_trained.txt',"w") 
file.write(t_file)
file.close()
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:256: UserWarning: Couldn't retrieve source code for container of type SoundRecognition_CNN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
###### Make change under this this line########

###############################################


### run model with several sets of hyperparameters
### the models and training results are saved

model_dir = 'model9/'
result_dir = 'result9/'

#wc_list = [1e-5]
#dr_list = [0.9]
#lr_list = [1e-4, 1e-5, 1e-6] ## LT is training                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                

wc_list = [1e-5]  #[1e-3, 1e-4, 1e-5]
dr_list = [0, 0.1, 0.5, 0.75, 0.9] #[0, 0.1, 0.5, 0.75, 0.9]
lr_list = [1e-4, 1e-5, 1e-6]   #no wc -4 w/ dr .75 and dr .9 at all lr
epochs = 1000
#dropout_rate = 0.5
#weight_decay = 1e-6

for try_wc in wc_list:
  for try_dr in dr_list:
    for try_lr in lr_list:
      m_save_path, f_save_path = getName(epochs, try_dr, try_wc, try_lr)
      print('Training: ', m_save_path)
      m, t_file = fit(epochs = epochs, 
                      train_bs = 100, 
                      n_train = n_train, 
                      validate_bs = 200, 
                      n_validate = n_validate,
                      dropout_rate = try_dr, 
                      weight_decay = try_wc, 
                      lr = try_lr,
                      tolerance = 0.1)

      torch.save(m, model_dir + m_save_path)
      file = open(result_dir + f_save_path,"w") 
      file.write(t_file)
      file.close()
# Out:
# Training:  mfcc_m_1000_dr0_wc1e-05_lr0.0001.pt
# Epoch:  10  | Loss:  tensor(5.2943, device='cuda:0')  | Accuracy:  tensor(0.9394, device='cuda:0')
# Epoch:  20  | Loss:  tensor(4.1601, device='cuda:0')  | Accuracy:  tensor(0.9450, device='cuda:0')
# Epoch:  30  | Loss:  tensor(3.9175, device='cuda:0')  | Accuracy:  tensor(0.9523, device='cuda:0')
# Epoch:  40  | Loss:  tensor(3.4764, device='cuda:0')  | Accuracy:  tensor(0.9588, device='cuda:0')
# Epoch:  50  | Loss:  tensor(3.6289, device='cuda:0')  | Accuracy:  tensor(0.9594, device='cuda:0')
# Epoch:  55  == Early stop due to an increase in validation loss
# Train Finished
# Training:  mfcc_m_1000_dr0_wc1e-05_lr1e-05.pt
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:256: UserWarning: Couldn't retrieve source code for container of type SoundRecognition_CNN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Epoch:  10  | Loss:  tensor(20.2371, device='cuda:0')  | Accuracy:  tensor(0.7215, device='cuda:0')
# Epoch:  20  | Loss:  tensor(12.2259, device='cuda:0')  | Accuracy:  tensor(0.8519, device='cuda:0')
# Epoch:  30  | Loss:  tensor(9.4483, device='cuda:0')  | Accuracy:  tensor(0.8946, device='cuda:0')
# Epoch:  40  | Loss:  tensor(8.0178, device='cuda:0')  | Accuracy:  tensor(0.9085, device='cuda:0')
# Epoch:  50  | Loss:  tensor(7.1052, device='cuda:0')  | Accuracy:  tensor(0.9187, device='cuda:0')
# Epoch:  60  | Loss:  tensor(6.4547, device='cuda:0')  | Accuracy:  tensor(0.9267, device='cuda:0')
# Epoch:  70  | Loss:  tensor(5.9594, device='cuda:0')  | Accuracy:  tensor(0.9327, device='cuda:0')
# Epoch:  80  | Loss:  tensor(5.5653, device='cuda:0')  | Accuracy:  tensor(0.9358, device='cuda:0')
# Epoch:  90  | Loss:  tensor(5.2406, device='cuda:0')  | Accuracy:  tensor(0.9394, device='cuda:0')
# Epoch:  100  | Loss:  tensor(4.9635, device='cuda:0')  | Accuracy:  tensor(0.9431, device='cuda:0')
# Epoch:  110  | Loss:  tensor(4.7280, device='cuda:0')  | Accuracy:  tensor(0.9450, device='cuda:0')
# Epoch:  120  | Loss:  tensor(4.5272, device='cuda:0')  | Accuracy:  tensor(0.9456, device='cuda:0')
# Epoch:  130  | Loss:  tensor(4.3581, device='cuda:0')  | Accuracy:  tensor(0.9479, device='cuda:0')
# Epoch:  140  | Loss:  tensor(4.2216, device='cuda:0')  | Accuracy:  tensor(0.9494, device='cuda:0')
# Epoch:  150  | Loss:  tensor(4.1169, device='cuda:0')  | Accuracy:  tensor(0.9488, device='cuda:0')
# Epoch:  160  | Loss:  tensor(4.0404, device='cuda:0')  | Accuracy:  tensor(0.9508, device='cuda:0')
# Epoch:  170  | Loss:  tensor(3.9880, device='cuda:0')  | Accuracy:  tensor(0.9508, device='cuda:0')
# Epoch:  180  | Loss:  tensor(3.9562, device='cuda:0')  | Accuracy:  tensor(0.9510, device='cuda:0')
# Epoch:  190  | Loss:  tensor(3.9389, device='cuda:0')  | Accuracy:  tensor(0.9515, device='cuda:0')
# Epoch:  200  | Loss:  tensor(3.9396, device='cuda:0')  | Accuracy:  tensor(0.9533, device='cuda:0')
# Epoch:  210  | Loss:  tensor(3.9580, device='cuda:0')  | Accuracy:  tensor(0.9546, device='cuda:0')
# Epoch:  220  | Loss:  tensor(3.9944, device='cuda:0')  | Accuracy:  tensor(0.9558, device='cuda:0')
# Epoch:  230  | Loss:  tensor(4.0379, device='cuda:0')  | Accuracy:  tensor(0.9560, device='cuda:0')
# Epoch:  240  | Loss:  tensor(4.0899, device='cuda:0')  | Accuracy:  tensor(0.9558, device='cuda:0')
# Epoch:  250  | Loss:  tensor(4.1635, device='cuda:0')  | Accuracy:  tensor(0.9565, device='cuda:0')
# Epoch:  260  | Loss:  tensor(4.2623, device='cuda:0')  | Accuracy:  tensor(0.9556, device='cuda:0')
# Epoch:  265  == Early stop due to an increase in validation loss
# Train Finished
# Training:  mfcc_m_1000_dr0_wc1e-05_lr1e-06.pt
# Epoch:  10  | Loss:  tensor(38.7003, device='cuda:0')  | Accuracy:  tensor(0.6691, device='cuda:0')
# Epoch:  20  | Loss:  tensor(35.1607, device='cuda:0')  | Accuracy:  tensor(0.6699, device='cuda:0')
# Epoch:  30  | Loss:  tensor(31.7634, device='cuda:0')  | Accuracy:  tensor(0.6716, device='cuda:0')
# Epoch:  40  | Loss:  tensor(28.6460, device='cuda:0')  | Accuracy:  tensor(0.6768, device='cuda:0')
# Epoch:  50  | Loss:  tensor(25.9484, device='cuda:0')  | Accuracy:  tensor(0.6887, device='cuda:0')
# Epoch:  60  | Loss:  tensor(23.6576, device='cuda:0')  | Accuracy:  tensor(0.7035, device='cuda:0')
# Epoch:  70  | Loss:  tensor(21.6980, device='cuda:0')  | Accuracy:  tensor(0.7252, device='cuda:0')
# Epoch:  80  | Loss:  tensor(20.0231, device='cuda:0')  | Accuracy:  tensor(0.7406, device='cuda:0')
# Epoch:  90  | Loss:  tensor(18.5859, device='cuda:0')  | Accuracy:  tensor(0.7582, device='cuda:0')
# Epoch:  100  | Loss:  tensor(17.3505, device='cuda:0')  | Accuracy:  tensor(0.7771, device='cuda:0')
# Epoch:  110  | Loss:  tensor(16.2917, device='cuda:0')  | Accuracy:  tensor(0.7942, device='cuda:0')
# Epoch:  120  | Loss:  tensor(15.3844, device='cuda:0')  | Accuracy:  tensor(0.8058, device='cuda:0')
# Epoch:  130  | Loss:  tensor(14.6027, device='cuda:0')  | Accuracy:  tensor(0.8164, device='cuda:0')
# Epoch:  140  | Loss:  tensor(13.9232, device='cuda:0')  | Accuracy:  tensor(0.8262, device='cuda:0')
# Epoch:  150  | Loss:  tensor(13.3287, device='cuda:0')  | Accuracy:  tensor(0.8328, device='cuda:0')
# Epoch:  160  | Loss:  tensor(12.8059, device='cuda:0')  | Accuracy:  tensor(0.8391, device='cuda:0')
# Epoch:  170  | Loss:  tensor(12.3425, device='cuda:0')  | Accuracy:  tensor(0.8449, device='cuda:0')
# Epoch:  180  | Loss:  tensor(11.9275, device='cuda:0')  | Accuracy:  tensor(0.8489, device='cuda:0')
# Epoch:  190  | Loss:  tensor(11.5532, device='cuda:0')  | Accuracy:  tensor(0.8547, device='cuda:0')
# Epoch:  200  | Loss:  tensor(11.2133, device='cuda:0')  | Accuracy:  tensor(0.8570, device='cuda:0')
# Epoch:  210  | Loss:  tensor(10.9030, device='cuda:0')  | Accuracy:  tensor(0.8599, device='cuda:0')
# Epoch:  220  | Loss:  tensor(10.6176, device='cuda:0')  | Accuracy:  tensor(0.8620, device='cuda:0')
# Epoch:  230  | Loss:  tensor(10.3538, device='cuda:0')  | Accuracy:  tensor(0.8655, device='cuda:0')
# Epoch:  240  | Loss:  tensor(10.1097, device='cuda:0')  | Accuracy:  tensor(0.8686, device='cuda:0')
# Epoch:  250  | Loss:  tensor(9.8824, device='cuda:0')  | Accuracy:  tensor(0.8714, device='cuda:0')
# Epoch:  260  | Loss:  tensor(9.6705, device='cuda:0')  | Accuracy:  tensor(0.8734, device='cuda:0')
# Epoch:  270  | Loss:  tensor(9.4721, device='cuda:0')  | Accuracy:  tensor(0.8761, device='cuda:0')
# Epoch:  280  | Loss:  tensor(9.2845, device='cuda:0')  | Accuracy:  tensor(0.8784, device='cuda:0')
# Epoch:  290  | Loss:  tensor(9.1067, device='cuda:0')  | Accuracy:  tensor(0.8805, device='cuda:0')
# Epoch:  300  | Loss:  tensor(8.9373, device='cuda:0')  | Accuracy:  tensor(0.8839, device='cuda:0')
# Epoch:  310  | Loss:  tensor(8.7763, device='cuda:0')  | Accuracy:  tensor(0.8862, device='cuda:0')
# Epoch:  320  | Loss:  tensor(8.6244, device='cuda:0')  | Accuracy:  tensor(0.8886, device='cuda:0')
# Epoch:  330  | Loss:  tensor(8.4802, device='cuda:0')  | Accuracy:  tensor(0.8897, device='cuda:0')
# Epoch:  340  | Loss:  tensor(8.3425, device='cuda:0')  | Accuracy:  tensor(0.8914, device='cuda:0')
# Epoch:  350  | Loss:  tensor(8.2112, device='cuda:0')  | Accuracy:  tensor(0.8939, device='cuda:0')
# Epoch:  360  | Loss:  tensor(8.0852, device='cuda:0')  | Accuracy:  tensor(0.8985, device='cuda:0')
# Epoch:  370  | Loss:  tensor(7.9643, device='cuda:0')  | Accuracy:  tensor(0.9008, device='cuda:0')
# Epoch:  380  | Loss:  tensor(7.8483, device='cuda:0')  | Accuracy:  tensor(0.9019, device='cuda:0')
# Epoch:  390  | Loss:  tensor(7.7366, device='cuda:0')  | Accuracy:  tensor(0.9035, device='cuda:0')
# Epoch:  400  | Loss:  tensor(7.6290, device='cuda:0')  | Accuracy:  tensor(0.9046, device='cuda:0')
# Epoch:  410  | Loss:  tensor(7.5257, device='cuda:0')  | Accuracy:  tensor(0.9063, device='cuda:0')
# Epoch:  420  | Loss:  tensor(7.4259, device='cuda:0')  | Accuracy:  tensor(0.9077, device='cuda:0')
# Epoch:  430  | Loss:  tensor(7.3298, device='cuda:0')  | Accuracy:  tensor(0.9094, device='cuda:0')
# Epoch:  440  | Loss:  tensor(7.2372, device='cuda:0')  | Accuracy:  tensor(0.9104, device='cuda:0')
# Epoch:  450  | Loss:  tensor(7.1480, device='cuda:0')  | Accuracy:  tensor(0.9110, device='cuda:0')
# Epoch:  460  | Loss:  tensor(7.0616, device='cuda:0')  | Accuracy:  tensor(0.9115, device='cuda:0')
# Epoch:  470  | Loss:  tensor(6.9779, device='cuda:0')  | Accuracy:  tensor(0.9129, device='cuda:0')
# Epoch:  480  | Loss:  tensor(6.8962, device='cuda:0')  | Accuracy:  tensor(0.9138, device='cuda:0')
# Epoch:  490  | Loss:  tensor(6.8170, device='cuda:0')  | Accuracy:  tensor(0.9158, device='cuda:0')
# Epoch:  500  | Loss:  tensor(6.7402, device='cuda:0')  | Accuracy:  tensor(0.9173, device='cuda:0')
# Epoch:  510  | Loss:  tensor(6.6650, device='cuda:0')  | Accuracy:  tensor(0.9190, device='cuda:0')
# Epoch:  520  | Loss:  tensor(6.5917, device='cuda:0')  | Accuracy:  tensor(0.9213, device='cuda:0')
# Epoch:  530  | Loss:  tensor(6.5209, device='cuda:0')  | Accuracy:  tensor(0.9231, device='cuda:0')
# Epoch:  540  | Loss:  tensor(6.4523, device='cuda:0')  | Accuracy:  tensor(0.9244, device='cuda:0')
# Epoch:  550  | Loss:  tensor(6.3857, device='cuda:0')  | Accuracy:  tensor(0.9260, device='cuda:0')
# Epoch:  560  | Loss:  tensor(6.3208, device='cuda:0')  | Accuracy:  tensor(0.9267, device='cuda:0')
# Epoch:  570  | Loss:  tensor(6.2573, device='cuda:0')  | Accuracy:  tensor(0.9287, device='cuda:0')
# Epoch:  580  | Loss:  tensor(6.1956, device='cuda:0')  | Accuracy:  tensor(0.9294, device='cuda:0')
# Epoch:  590  | Loss:  tensor(6.1356, device='cuda:0')  | Accuracy:  tensor(0.9300, device='cuda:0')
# Epoch:  600  | Loss:  tensor(6.0774, device='cuda:0')  | Accuracy:  tensor(0.9306, device='cuda:0')
# Epoch:  610  | Loss:  tensor(6.0204, device='cuda:0')  | Accuracy:  tensor(0.9313, device='cuda:0')
# Epoch:  620  | Loss:  tensor(5.9650, device='cuda:0')  | Accuracy:  tensor(0.9319, device='cuda:0')
# Epoch:  630  | Loss:  tensor(5.9108, device='cuda:0')  | Accuracy:  tensor(0.9317, device='cuda:0')
# Epoch:  640  | Loss:  tensor(5.8580, device='cuda:0')  | Accuracy:  tensor(0.9325, device='cuda:0')
# Epoch:  650  | Loss:  tensor(5.8063, device='cuda:0')  | Accuracy:  tensor(0.9325, device='cuda:0')
# Epoch:  660  | Loss:  tensor(5.7557, device='cuda:0')  | Accuracy:  tensor(0.9327, device='cuda:0')
# Epoch:  670  | Loss:  tensor(5.7066, device='cuda:0')  | Accuracy:  tensor(0.9331, device='cuda:0')
# Epoch:  680  | Loss:  tensor(5.6589, device='cuda:0')  | Accuracy:  tensor(0.9335, device='cuda:0')
# Epoch:  690  | Loss:  tensor(5.6122, device='cuda:0')  | Accuracy:  tensor(0.9346, device='cuda:0')
# Epoch:  700  | Loss:  tensor(5.5663, device='cuda:0')  | Accuracy:  tensor(0.9352, device='cuda:0')
# Epoch:  710  | Loss:  tensor(5.5217, device='cuda:0')  | Accuracy:  tensor(0.9358, device='cuda:0')
# Epoch:  720  | Loss:  tensor(5.4779, device='cuda:0')  | Accuracy:  tensor(0.9363, device='cuda:0')
# Epoch:  730  | Loss:  tensor(5.4352, device='cuda:0')  | Accuracy:  tensor(0.9365, device='cuda:0')
# Epoch:  740  | Loss:  tensor(5.3934, device='cuda:0')  | Accuracy:  tensor(0.9369, device='cuda:0')
# Epoch:  750  | Loss:  tensor(5.3524, device='cuda:0')  | Accuracy:  tensor(0.9375, device='cuda:0')
# Epoch:  760  | Loss:  tensor(5.3126, device='cuda:0')  | Accuracy:  tensor(0.9377, device='cuda:0')
# Epoch:  770  | Loss:  tensor(5.2737, device='cuda:0')  | Accuracy:  tensor(0.9381, device='cuda:0')
# Epoch:  780  | Loss:  tensor(5.2356, device='cuda:0')  | Accuracy:  tensor(0.9390, device='cuda:0')
# Epoch:  790  | Loss:  tensor(5.1984, device='cuda:0')  | Accuracy:  tensor(0.9392, device='cuda:0')
# Epoch:  800  | Loss:  tensor(5.1621, device='cuda:0')  | Accuracy:  tensor(0.9402, device='cuda:0')
# Epoch:  810  | Loss:  tensor(5.1270, device='cuda:0')  | Accuracy:  tensor(0.9408, device='cuda:0')
# Epoch:  820  | Loss:  tensor(5.0923, device='cuda:0')  | Accuracy:  tensor(0.9406, device='cuda:0')
# Epoch:  830  | Loss:  tensor(5.0583, device='cuda:0')  | Accuracy:  tensor(0.9406, device='cuda:0')
# Epoch:  840  | Loss:  tensor(5.0252, device='cuda:0')  | Accuracy:  tensor(0.9404, device='cuda:0')
# Epoch:  850  | Loss:  tensor(4.9928, device='cuda:0')  | Accuracy:  tensor(0.9404, device='cuda:0')
# Epoch:  860  | Loss:  tensor(4.9610, device='cuda:0')  | Accuracy:  tensor(0.9406, device='cuda:0')
# Epoch:  870  | Loss:  tensor(4.9299, device='cuda:0')  | Accuracy:  tensor(0.9410, device='cuda:0')
# Epoch:  880  | Loss:  tensor(4.8997, device='cuda:0')  | Accuracy:  tensor(0.9412, device='cuda:0')
# Epoch:  890  | Loss:  tensor(4.8702, device='cuda:0')  | Accuracy:  tensor(0.9413, device='cuda:0')
# Epoch:  900  | Loss:  tensor(4.8416, device='cuda:0')  | Accuracy:  tensor(0.9413, device='cuda:0')
# Epoch:  910  | Loss:  tensor(4.8135, device='cuda:0')  | Accuracy:  tensor(0.9413, device='cuda:0')
# Epoch:  920  | Loss:  tensor(4.7859, device='cuda:0')  | Accuracy:  tensor(0.9415, device='cuda:0')
# Epoch:  930  | Loss:  tensor(4.7590, device='cuda:0')  | Accuracy:  tensor(0.9417, device='cuda:0')
# Epoch:  940  | Loss:  tensor(4.7328, device='cuda:0')  | Accuracy:  tensor(0.9419, device='cuda:0')
# Epoch:  950  | Loss:  tensor(4.7071, device='cuda:0')  | Accuracy:  tensor(0.9419, device='cuda:0')
# Epoch:  960  | Loss:  tensor(4.6819, device='cuda:0')  | Accuracy:  tensor(0.9417, device='cuda:0')
# Epoch:  970  | Loss:  tensor(4.6576, device='cuda:0')  | Accuracy:  tensor(0.9413, device='cuda:0')
# Epoch:  980  | Loss:  tensor(4.6340, device='cuda:0')  | Accuracy:  tensor(0.9413, device='cuda:0')
# Epoch:  990  | Loss:  tensor(4.6109, device='cuda:0')  | Accuracy:  tensor(0.9415, device='cuda:0')
# Epoch:  1000  | Loss:  tensor(4.5884, device='cuda:0')  | Accuracy:  tensor(0.9419, device='cuda:0')
# Train Finished
# Training:  mfcc_m_1000_dr0.1_wc1e-05_lr0.0001.pt
# Epoch:  10  | Loss:  tensor(6.0408, device='cuda:0')  | Accuracy:  tensor(0.9385, device='cuda:0')
# Epoch:  20  | Loss:  tensor(3.9180, device='cuda:0')  | Accuracy:  tensor(0.9558, device='cuda:0')
# Epoch:  30  | Loss:  tensor(3.2836, device='cuda:0')  | Accuracy:  tensor(0.9592, device='cuda:0')
# Epoch:  39  == Early stop due to an increase in validation loss
# Train Finished
# Training:  mfcc_m_1000_dr0.1_wc1e-05_lr1e-05.pt
# Epoch:  10  | Loss:  tensor(25.7983, device='cuda:0')  | Accuracy:  tensor(0.7266, device='cuda:0')
# Epoch:  20  | Loss:  tensor(15.2384, device='cuda:0')  | Accuracy:  tensor(0.8629, device='cuda:0')
# Epoch:  30  | Loss:  tensor(11.2761, device='cuda:0')  | Accuracy:  tensor(0.8994, device='cuda:0')
# Epoch:  40  | Loss:  tensor(9.1805, device='cuda:0')  | Accuracy:  tensor(0.9150, device='cuda:0')
# Epoch:  50  | Loss:  tensor(7.9401, device='cuda:0')  | Accuracy:  tensor(0.9250, device='cuda:0')
# Epoch:  60  | Loss:  tensor(7.0559, device='cuda:0')  | Accuracy:  tensor(0.9337, device='cuda:0')
# Epoch:  70  | Loss:  tensor(6.4292, device='cuda:0')  | Accuracy:  tensor(0.9387, device='cuda:0')
# Epoch:  80  | Loss:  tensor(5.9347, device='cuda:0')  | Accuracy:  tensor(0.9419, device='cuda:0')
# Epoch:  90  | Loss:  tensor(5.5144, device='cuda:0')  | Accuracy:  tensor(0.9446, device='cuda:0')
# Epoch:  100  | Loss:  tensor(5.2001, device='cuda:0')  | Accuracy:  tensor(0.9477, device='cuda:0')
# Epoch:  110  | Loss:  tensor(4.9273, device='cuda:0')  | Accuracy:  tensor(0.9488, device='cuda:0')
# Epoch:  120  | Loss:  tensor(4.6947, device='cuda:0')  | Accuracy:  tensor(0.9492, device='cuda:0')
# Epoch:  130  | Loss:  tensor(4.4925, device='cuda:0')  | Accuracy:  tensor(0.9506, device='cuda:0')
# Epoch:  140  | Loss:  tensor(4.3760, device='cuda:0')  | Accuracy:  tensor(0.9506, device='cuda:0')
# Epoch:  150  | Loss:  tensor(4.2152, device='cuda:0')  | Accuracy:  tensor(0.9510, device='cuda:0')
# Epoch:  160  | Loss:  tensor(4.0906, device='cuda:0')  | Accuracy:  tensor(0.9508, device='cuda:0')
# Epoch:  170  | Loss:  tensor(4.0294, device='cuda:0')  | Accuracy:  tensor(0.9521, device='cuda:0')
# Epoch:  180  | Loss:  tensor(3.8955, device='cuda:0')  | Accuracy:  tensor(0.9533, device='cuda:0')
# Epoch:  190  | Loss:  tensor(3.8580, device='cuda:0')  | Accuracy:  tensor(0.9519, device='cuda:0')
# Epoch:  200  | Loss:  tensor(3.7554, device='cuda:0')  | Accuracy:  tensor(0.9529, device='cuda:0')
# Epoch:  210  | Loss:  tensor(3.8013, device='cuda:0')  | Accuracy:  tensor(0.9535, device='cuda:0')
# Epoch:  220  | Loss:  tensor(3.7128, device='cuda:0')  | Accuracy:  tensor(0.9540, device='cuda:0')
# Epoch:  230  | Loss:  tensor(3.7040, device='cuda:0')  | Accuracy:  tensor(0.9540, device='cuda:0')
# Epoch:  240  | Loss:  tensor(3.6779, device='cuda:0')  | Accuracy:  tensor(0.9538, device='cuda:0')
# Epoch:  250  | Loss:  tensor(3.7171, device='cuda:0')  | Accuracy:  tensor(0.9521, device='cuda:0')
# Epoch:  260  | Loss:  tensor(3.6628, device='cuda:0')  | Accuracy:  tensor(0.9535, device='cuda:0')
# Epoch:  270  | Loss:  tensor(3.6275, device='cuda:0')  | Accuracy:  tensor(0.9550, device='cuda:0')
# Epoch:  280  | Loss:  tensor(3.6495, device='cuda:0')  | Accuracy:  tensor(0.9552, device='cuda:0')
# Epoch:  290  | Loss:  tensor(3.6056, device='cuda:0')  | Accuracy:  tensor(0.9546, device='cuda:0')
# Epoch:  300  | Loss:  tensor(3.6538, device='cuda:0')  | Accuracy:  tensor(0.9542, device='cuda:0')
# Epoch:  310  | Loss:  tensor(3.6157, device='cuda:0')  | Accuracy:  tensor(0.9546, device='cuda:0')
# Epoch:  320  | Loss:  tensor(3.6690, device='cuda:0')  | Accuracy:  tensor(0.9573, device='cuda:0')
# Epoch:  330  | Loss:  tensor(3.7243, device='cuda:0')  | Accuracy:  tensor(0.9542, device='cuda:0')
# Epoch:  340  | Loss:  tensor(3.7288, device='cuda:0')  | Accuracy:  tensor(0.9558, device='cuda:0')
# Epoch:  350  | Loss:  tensor(3.6533, device='cuda:0')  | Accuracy:  tensor(0.9560, device='cuda:0')
# Epoch:  360  | Loss:  tensor(3.6509, device='cuda:0')  | Accuracy:  tensor(0.9558, device='cuda:0')
# Epoch:  370  | Loss:  tensor(3.6885, device='cuda:0')  | Accuracy:  tensor(0.9563, device='cuda:0')
# Epoch:  380  | Loss:  tensor(3.7741, device='cuda:0')  | Accuracy:  tensor(0.9542, device='cuda:0')
# Epoch:  390  | Loss:  tensor(3.8468, device='cuda:0')  | Accuracy:  tensor(0.9556, device='cuda:0')
# Epoch:  400  | Loss:  tensor(3.7767, device='cuda:0')  | Accuracy:  tensor(0.9556, device='cuda:0')
# Epoch:  410  | Loss:  tensor(3.7750, device='cuda:0')  | Accuracy:  tensor(0.9544, device='cuda:0')
# Epoch:  420  | Loss:  tensor(3.7857, device='cuda:0')  | Accuracy:  tensor(0.9563, device='cuda:0')
# Epoch:  430  | Loss:  tensor(3.8622, device='cuda:0')  | Accuracy:  tensor(0.9548, device='cuda:0')
# Epoch:  431  == Early stop due to an increase in validation loss
# Train Finished
# Training:  mfcc_m_1000_dr0.1_wc1e-05_lr1e-06.pt
# Epoch:  10  | Loss:  tensor(39.0045, device='cuda:0')  | Accuracy:  tensor(0.6689, device='cuda:0')
# Epoch:  20  | Loss:  tensor(35.8227, device='cuda:0')  | Accuracy:  tensor(0.6739, device='cuda:0')
# Epoch:  30  | Loss:  tensor(32.8418, device='cuda:0')  | Accuracy:  tensor(0.6843, device='cuda:0')
# Epoch:  40  | Loss:  tensor(30.0828, device='cuda:0')  | Accuracy:  tensor(0.7029, device='cuda:0')
# Epoch:  50  | Loss:  tensor(27.5446, device='cuda:0')  | Accuracy:  tensor(0.7239, device='cuda:0')
# Epoch:  60  | Loss:  tensor(25.3223, device='cuda:0')  | Accuracy:  tensor(0.7401, device='cuda:0')
# Epoch:  70  | Loss:  tensor(23.4096, device='cuda:0')  | Accuracy:  tensor(0.7560, device='cuda:0')
# Epoch:  80  | Loss:  tensor(21.6934, device='cuda:0')  | Accuracy:  tensor(0.7750, device='cuda:0')
# Epoch:  90  | Loss:  tensor(20.2520, device='cuda:0')  | Accuracy:  tensor(0.7904, device='cuda:0')
# Epoch:  100  | Loss:  tensor(18.9792, device='cuda:0')  | Accuracy:  tensor(0.8069, device='cuda:0')
# Epoch:  110  | Loss:  tensor(17.8714, device='cuda:0')  | Accuracy:  tensor(0.8205, device='cuda:0')
# Epoch:  120  | Loss:  tensor(16.8985, device='cuda:0')  | Accuracy:  tensor(0.8305, device='cuda:0')
# Epoch:  130  | Loss:  tensor(16.0656, device='cuda:0')  | Accuracy:  tensor(0.8433, device='cuda:0')
# Epoch:  140  | Loss:  tensor(15.3217, device='cuda:0')  | Accuracy:  tensor(0.8506, device='cuda:0')
# Epoch:  150  | Loss:  tensor(14.6714, device='cuda:0')  | Accuracy:  tensor(0.8565, device='cuda:0')
# Epoch:  160  | Loss:  tensor(14.0745, device='cuda:0')  | Accuracy:  tensor(0.8627, device='cuda:0')
# Epoch:  170  | Loss:  tensor(13.5206, device='cuda:0')  | Accuracy:  tensor(0.8667, device='cuda:0')
# Epoch:  180  | Loss:  tensor(13.0369, device='cuda:0')  | Accuracy:  tensor(0.8721, device='cuda:0')
# Epoch:  190  | Loss:  tensor(12.6206, device='cuda:0')  | Accuracy:  tensor(0.8788, device='cuda:0')
# Epoch:  200  | Loss:  tensor(12.2185, device='cuda:0')  | Accuracy:  tensor(0.8835, device='cuda:0')
# Epoch:  210  | Loss:  tensor(11.8625, device='cuda:0')  | Accuracy:  tensor(0.8847, device='cuda:0')
# Epoch:  220  | Loss:  tensor(11.5121, device='cuda:0')  | Accuracy:  tensor(0.8892, device='cuda:0')
# Epoch:  230  | Loss:  tensor(11.2155, device='cuda:0')  | Accuracy:  tensor(0.8940, device='cuda:0')
# Epoch:  240  | Loss:  tensor(10.9188, device='cuda:0')  | Accuracy:  tensor(0.8983, device='cuda:0')
# Epoch:  250  | Loss:  tensor(10.6384, device='cuda:0')  | Accuracy:  tensor(0.9006, device='cuda:0')
# Epoch:  260  | Loss:  tensor(10.4009, device='cuda:0')  | Accuracy:  tensor(0.9029, device='cuda:0')
# Epoch:  270  | Loss:  tensor(10.1622, device='cuda:0')  | Accuracy:  tensor(0.9035, device='cuda:0')
# Epoch:  280  | Loss:  tensor(9.9338, device='cuda:0')  | Accuracy:  tensor(0.9063, device='cuda:0')
# Epoch:  290  | Loss:  tensor(9.7278, device='cuda:0')  | Accuracy:  tensor(0.9075, device='cuda:0')
# Epoch:  300  | Loss:  tensor(9.5340, device='cuda:0')  | Accuracy:  tensor(0.9104, device='cuda:0')
# Epoch:  310  | Loss:  tensor(9.3467, device='cuda:0')  | Accuracy:  tensor(0.9110, device='cuda:0')
# Epoch:  320  | Loss:  tensor(9.1876, device='cuda:0')  | Accuracy:  tensor(0.9127, device='cuda:0')
# Epoch:  330  | Loss:  tensor(9.0210, device='cuda:0')  | Accuracy:  tensor(0.9146, device='cuda:0')
# Epoch:  340  | Loss:  tensor(8.8425, device='cuda:0')  | Accuracy:  tensor(0.9163, device='cuda:0')
# Epoch:  350  | Loss:  tensor(8.6929, device='cuda:0')  | Accuracy:  tensor(0.9171, device='cuda:0')
# Epoch:  360  | Loss:  tensor(8.5493, device='cuda:0')  | Accuracy:  tensor(0.9183, device='cuda:0')
# Epoch:  370  | Loss:  tensor(8.4193, device='cuda:0')  | Accuracy:  tensor(0.9202, device='cuda:0')
# Epoch:  380  | Loss:  tensor(8.2683, device='cuda:0')  | Accuracy:  tensor(0.9215, device='cuda:0')
# Epoch:  390  | Loss:  tensor(8.1602, device='cuda:0')  | Accuracy:  tensor(0.9227, device='cuda:0')
# Epoch:  400  | Loss:  tensor(8.0394, device='cuda:0')  | Accuracy:  tensor(0.9237, device='cuda:0')
# Epoch:  410  | Loss:  tensor(7.9143, device='cuda:0')  | Accuracy:  tensor(0.9258, device='cuda:0')
# Epoch:  420  | Loss:  tensor(7.7963, device='cuda:0')  | Accuracy:  tensor(0.9258, device='cuda:0')
# Epoch:  430  | Loss:  tensor(7.6776, device='cuda:0')  | Accuracy:  tensor(0.9260, device='cuda:0')
# Epoch:  440  | Loss:  tensor(7.5851, device='cuda:0')  | Accuracy:  tensor(0.9283, device='cuda:0')
# Epoch:  450  | Loss:  tensor(7.4780, device='cuda:0')  | Accuracy:  tensor(0.9281, device='cuda:0')
# Epoch:  460  | Loss:  tensor(7.3812, device='cuda:0')  | Accuracy:  tensor(0.9294, device='cuda:0')
# Epoch:  470  | Loss:  tensor(7.3018, device='cuda:0')  | Accuracy:  tensor(0.9304, device='cuda:0')
# Epoch:  480  | Loss:  tensor(7.2040, device='cuda:0')  | Accuracy:  tensor(0.9315, device='cuda:0')
# Epoch:  490  | Loss:  tensor(7.1242, device='cuda:0')  | Accuracy:  tensor(0.9327, device='cuda:0')
# Epoch:  500  | Loss:  tensor(7.0421, device='cuda:0')  | Accuracy:  tensor(0.9333, device='cuda:0')
# Epoch:  510  | Loss:  tensor(6.9636, device='cuda:0')  | Accuracy:  tensor(0.9344, device='cuda:0')
# Epoch:  520  | Loss:  tensor(6.8751, device='cuda:0')  | Accuracy:  tensor(0.9346, device='cuda:0')
# Epoch:  530  | Loss:  tensor(6.7950, device='cuda:0')  | Accuracy:  tensor(0.9362, device='cuda:0')
# Epoch:  540  | Loss:  tensor(6.7230, device='cuda:0')  | Accuracy:  tensor(0.9365, device='cuda:0')
# Epoch:  550  | Loss:  tensor(6.6499, device='cuda:0')  | Accuracy:  tensor(0.9371, device='cuda:0')
# Epoch:  560  | Loss:  tensor(6.5757, device='cuda:0')  | Accuracy:  tensor(0.9377, device='cuda:0')
# Epoch:  570  | Loss:  tensor(6.5189, device='cuda:0')  | Accuracy:  tensor(0.9383, device='cuda:0')
# Epoch:  580  | Loss:  tensor(6.4401, device='cuda:0')  | Accuracy:  tensor(0.9381, device='cuda:0')
# Epoch:  590  | Loss:  tensor(6.3679, device='cuda:0')  | Accuracy:  tensor(0.9387, device='cuda:0')
# Epoch:  600  | Loss:  tensor(6.3155, device='cuda:0')  | Accuracy:  tensor(0.9392, device='cuda:0')
# Epoch:  610  | Loss:  tensor(6.2546, device='cuda:0')  | Accuracy:  tensor(0.9406, device='cuda:0')
# Epoch:  620  | Loss:  tensor(6.1908, device='cuda:0')  | Accuracy:  tensor(0.9404, device='cuda:0')
# Epoch:  630  | Loss:  tensor(6.1374, device='cuda:0')  | Accuracy:  tensor(0.9404, device='cuda:0')
# Epoch:  640  | Loss:  tensor(6.0700, device='cuda:0')  | Accuracy:  tensor(0.9404, device='cuda:0')
# Epoch:  650  | Loss:  tensor(6.0072, device='cuda:0')  | Accuracy:  tensor(0.9413, device='cuda:0')
# Epoch:  660  | Loss:  tensor(5.9531, device='cuda:0')  | Accuracy:  tensor(0.9415, device='cuda:0')
# Epoch:  670  | Loss:  tensor(5.9116, device='cuda:0')  | Accuracy:  tensor(0.9431, device='cuda:0')
# Epoch:  680  | Loss:  tensor(5.8579, device='cuda:0')  | Accuracy:  tensor(0.9438, device='cuda:0')
# Epoch:  690  | Loss:  tensor(5.8103, device='cuda:0')  | Accuracy:  tensor(0.9437, device='cuda:0')
# Epoch:  700  | Loss:  tensor(5.7525, device='cuda:0')  | Accuracy:  tensor(0.9440, device='cuda:0')
# Epoch:  710  | Loss:  tensor(5.7121, device='cuda:0')  | Accuracy:  tensor(0.9444, device='cuda:0')
# Epoch:  720  | Loss:  tensor(5.6646, device='cuda:0')  | Accuracy:  tensor(0.9446, device='cuda:0')
# Epoch:  730  | Loss:  tensor(5.6182, device='cuda:0')  | Accuracy:  tensor(0.9446, device='cuda:0')
# Epoch:  740  | Loss:  tensor(5.5740, device='cuda:0')  | Accuracy:  tensor(0.9442, device='cuda:0')
# Epoch:  750  | Loss:  tensor(5.5298, device='cuda:0')  | Accuracy:  tensor(0.9450, device='cuda:0')
# Epoch:  760  | Loss:  tensor(5.4831, device='cuda:0')  | Accuracy:  tensor(0.9456, device='cuda:0')
# Epoch:  770  | Loss:  tensor(5.4396, device='cuda:0')  | Accuracy:  tensor(0.9454, device='cuda:0')
# Epoch:  780  | Loss:  tensor(5.4001, device='cuda:0')  | Accuracy:  tensor(0.9456, device='cuda:0')
# Epoch:  790  | Loss:  tensor(5.3640, device='cuda:0')  | Accuracy:  tensor(0.9462, device='cuda:0')
# Epoch:  800  | Loss:  tensor(5.3202, device='cuda:0')  | Accuracy:  tensor(0.9458, device='cuda:0')
# Epoch:  810  | Loss:  tensor(5.2880, device='cuda:0')  | Accuracy:  tensor(0.9465, device='cuda:0')
# Epoch:  820  | Loss:  tensor(5.2447, device='cuda:0')  | Accuracy:  tensor(0.9469, device='cuda:0')
# Epoch:  830  | Loss:  tensor(5.2141, device='cuda:0')  | Accuracy:  tensor(0.9465, device='cuda:0')
# Epoch:  840  | Loss:  tensor(5.1675, device='cuda:0')  | Accuracy:  tensor(0.9462, device='cuda:0')
# Epoch:  850  | Loss:  tensor(5.1373, device='cuda:0')  | Accuracy:  tensor(0.9467, device='cuda:0')
# Epoch:  860  | Loss:  tensor(5.1065, device='cuda:0')  | Accuracy:  tensor(0.9465, device='cuda:0')
# Epoch:  870  | Loss:  tensor(5.0797, device='cuda:0')  | Accuracy:  tensor(0.9479, device='cuda:0')
# Epoch:  880  | Loss:  tensor(5.0327, device='cuda:0')  | Accuracy:  tensor(0.9477, device='cuda:0')
# Epoch:  890  | Loss:  tensor(5.0001, device='cuda:0')  | Accuracy:  tensor(0.9483, device='cuda:0')
# Epoch:  900  | Loss:  tensor(4.9636, device='cuda:0')  | Accuracy:  tensor(0.9477, device='cuda:0')
# Epoch:  910  | Loss:  tensor(4.9361, device='cuda:0')  | Accuracy:  tensor(0.9479, device='cuda:0')
# Epoch:  920  | Loss:  tensor(4.9141, device='cuda:0')  | Accuracy:  tensor(0.9483, device='cuda:0')
# Epoch:  930  | Loss:  tensor(4.8857, device='cuda:0')  | Accuracy:  tensor(0.9477, device='cuda:0')
# Epoch:  940  | Loss:  tensor(4.8484, device='cuda:0')  | Accuracy:  tensor(0.9483, device='cuda:0')
# Epoch:  950  | Loss:  tensor(4.8195, device='cuda:0')  | Accuracy:  tensor(0.9488, device='cuda:0')
# Epoch:  960  | Loss:  tensor(4.7974, device='cuda:0')  | Accuracy:  tensor(0.9490, device='cuda:0')
# Epoch:  970  | Loss:  tensor(4.7582, device='cuda:0')  | Accuracy:  tensor(0.9481, device='cuda:0')
# Epoch:  980  | Loss:  tensor(4.7347, device='cuda:0')  | Accuracy:  tensor(0.9492, device='cuda:0')
# Epoch:  990  | Loss:  tensor(4.7099, device='cuda:0')  | Accuracy:  tensor(0.9490, device='cuda:0')
# Epoch:  1000  | Loss:  tensor(4.6745, device='cuda:0')  | Accuracy:  tensor(0.9488, device='cuda:0')
# Train Finished
# Training:  mfcc_m_1000_dr0.5_wc1e-05_lr0.0001.pt
# Epoch:  10  | Loss:  tensor(20.3954, device='cuda:0')  | Accuracy:  tensor(0.8634, device='cuda:0')
# Epoch:  20  | Loss:  tensor(12.5732, device='cuda:0')  | Accuracy:  tensor(0.9108, device='cuda:0')
# Epoch:  30  | Loss:  tensor(9.5881, device='cuda:0')  | Accuracy:  tensor(0.9254, device='cuda:0')
# Epoch:  40  | Loss:  tensor(7.8409, device='cuda:0')  | Accuracy:  tensor(0.9387, device='cuda:0')
# Epoch:  50  | Loss:  tensor(7.0697, device='cuda:0')  | Accuracy:  tensor(0.9417, device='cuda:0')
# Epoch:  60  | Loss:  tensor(6.3338, device='cuda:0')  | Accuracy:  tensor(0.9508, device='cuda:0')
# Epoch:  70  | Loss:  tensor(5.6795, device='cuda:0')  | Accuracy:  tensor(0.9515, device='cuda:0')
# Epoch:  80  | Loss:  tensor(5.0996, device='cuda:0')  | Accuracy:  tensor(0.9554, device='cuda:0')
# Epoch:  90  | Loss:  tensor(4.7552, device='cuda:0')  | Accuracy:  tensor(0.9563, device='cuda:0')
# Epoch:  100  | Loss:  tensor(4.5718, device='cuda:0')  | Accuracy:  tensor(0.9556, device='cuda:0')
# Epoch:  110  | Loss:  tensor(4.2361, device='cuda:0')  | Accuracy:  tensor(0.9600, device='cuda:0')
# Epoch:  120  | Loss:  tensor(4.0822, device='cuda:0')  | Accuracy:  tensor(0.9604, device='cuda:0')
# Epoch:  130  | Loss:  tensor(4.0218, device='cuda:0')  | Accuracy:  tensor(0.9579, device='cuda:0')
# Epoch:  140  | Loss:  tensor(3.7965, device='cuda:0')  | Accuracy:  tensor(0.9592, device='cuda:0')
# Epoch:  150  | Loss:  tensor(3.6727, device='cuda:0')  | Accuracy:  tensor(0.9587, device='cuda:0')
# Epoch:  160  | Loss:  tensor(3.7305, device='cuda:0')  | Accuracy:  tensor(0.9583, device='cuda:0')
# Epoch:  170  | Loss:  tensor(3.7991, device='cuda:0')  | Accuracy:  tensor(0.9552, device='cuda:0')
# Epoch:  180  | Loss:  tensor(3.5589, device='cuda:0')  | Accuracy:  tensor(0.9621, device='cuda:0')
# Epoch:  190  | Loss:  tensor(3.5662, device='cuda:0')  | Accuracy:  tensor(0.9590, device='cuda:0')
# Epoch:  200  | Loss:  tensor(3.3562, device='cuda:0')  | Accuracy:  tensor(0.9629, device='cuda:0')
# Epoch:  210  | Loss:  tensor(3.3716, device='cuda:0')  | Accuracy:  tensor(0.9615, device='cuda:0')
# Epoch:  220  | Loss:  tensor(3.3514, device='cuda:0')  | Accuracy:  tensor(0.9612, device='cuda:0')
# Epoch:  230  | Loss:  tensor(3.3575, device='cuda:0')  | Accuracy:  tensor(0.9638, device='cuda:0')
# Epoch:  240  | Loss:  tensor(3.2616, device='cuda:0')  | Accuracy:  tensor(0.9635, device='cuda:0')
# Epoch:  250  | Loss:  tensor(3.2738, device='cuda:0')  | Accuracy:  tensor(0.9625, device='cuda:0')
# Epoch:  260  | Loss:  tensor(3.4114, device='cuda:0')  | Accuracy:  tensor(0.9598, device='cuda:0')
# Epoch:  270  | Loss:  tensor(3.1365, device='cuda:0')  | Accuracy:  tensor(0.9650, device='cuda:0')
# Epoch:  280  | Loss:  tensor(3.1400, device='cuda:0')  | Accuracy:  tensor(0.9656, device='cuda:0')
# Epoch:  290  | Loss:  tensor(3.1197, device='cuda:0')  | Accuracy:  tensor(0.9642, device='cuda:0')
# Epoch:  300  | Loss:  tensor(3.0451, device='cuda:0')  | Accuracy:  tensor(0.9648, device='cuda:0')
# Epoch:  310  | Loss:  tensor(3.0932, device='cuda:0')  | Accuracy:  tensor(0.9635, device='cuda:0')
# Epoch:  320  | Loss:  tensor(3.1731, device='cuda:0')  | Accuracy:  tensor(0.9635, device='cuda:0')
# Epoch:  330  | Loss:  tensor(3.0623, device='cuda:0')  | Accuracy:  tensor(0.9637, device='cuda:0')
# Epoch:  340  | Loss:  tensor(3.0369, device='cuda:0')  | Accuracy:  tensor(0.9637, device='cuda:0')
# Epoch:  350  | Loss:  tensor(2.9948, device='cuda:0')  | Accuracy:  tensor(0.9652, device='cuda:0')
# Epoch:  360  | Loss:  tensor(2.8476, device='cuda:0')  | Accuracy:  tensor(0.9679, device='cuda:0')
# Epoch:  370  | Loss:  tensor(2.8643, device='cuda:0')  | Accuracy:  tensor(0.9665, device='cuda:0')
# Epoch:  380  | Loss:  tensor(2.9678, device='cuda:0')  | Accuracy:  tensor(0.9669, device='cuda:0')
# Epoch:  387  == Early stop due to an increase in validation loss
# Train Finished
# Training:  mfcc_m_1000_dr0.5_wc1e-05_lr1e-05.pt
# Epoch:  10  | Loss:  tensor(36.5572, device='cuda:0')  | Accuracy:  tensor(0.6902, device='cuda:0')
# Epoch:  20  | Loss:  tensor(33.9770, device='cuda:0')  | Accuracy:  tensor(0.7393, device='cuda:0')
# Epoch:  30  | Loss:  tensor(30.3279, device='cuda:0')  | Accuracy:  tensor(0.7768, device='cuda:0')
# Epoch:  40  | Loss:  tensor(26.5212, device='cuda:0')  | Accuracy:  tensor(0.8052, device='cuda:0')
# Epoch:  50  | Loss:  tensor(23.7219, device='cuda:0')  | Accuracy:  tensor(0.8277, device='cuda:0')
# Epoch:  60  | Loss:  tensor(21.3958, device='cuda:0')  | Accuracy:  tensor(0.8440, device='cuda:0')
# Epoch:  70  | Loss:  tensor(19.3735, device='cuda:0')  | Accuracy:  tensor(0.8579, device='cuda:0')
# Epoch:  80  | Loss:  tensor(17.6429, device='cuda:0')  | Accuracy:  tensor(0.8669, device='cuda:0')
# Epoch:  90  | Loss:  tensor(16.3349, device='cuda:0')  | Accuracy:  tensor(0.8754, device='cuda:0')
# Epoch:  100  | Loss:  tensor(15.2631, device='cuda:0')  | Accuracy:  tensor(0.8833, device='cuda:0')
# Epoch:  110  | Loss:  tensor(14.2870, device='cuda:0')  | Accuracy:  tensor(0.8900, device='cuda:0')
# Epoch:  120  | Loss:  tensor(13.4869, device='cuda:0')  | Accuracy:  tensor(0.8976, device='cuda:0')
# Epoch:  130  | Loss:  tensor(12.7553, device='cuda:0')  | Accuracy:  tensor(0.9018, device='cuda:0')
# Epoch:  140  | Loss:  tensor(12.1160, device='cuda:0')  | Accuracy:  tensor(0.9068, device='cuda:0')
# Epoch:  150  | Loss:  tensor(11.4367, device='cuda:0')  | Accuracy:  tensor(0.9095, device='cuda:0')
# Epoch:  160  | Loss:  tensor(11.0470, device='cuda:0')  | Accuracy:  tensor(0.9114, device='cuda:0')
# Epoch:  170  | Loss:  tensor(10.6650, device='cuda:0')  | Accuracy:  tensor(0.9156, device='cuda:0')
# Epoch:  180  | Loss:  tensor(10.3466, device='cuda:0')  | Accuracy:  tensor(0.9139, device='cuda:0')
# Epoch:  190  | Loss:  tensor(10.0133, device='cuda:0')  | Accuracy:  tensor(0.9187, device='cuda:0')
# Epoch:  200  | Loss:  tensor(9.7068, device='cuda:0')  | Accuracy:  tensor(0.9220, device='cuda:0')
# Epoch:  210  | Loss:  tensor(9.4242, device='cuda:0')  | Accuracy:  tensor(0.9212, device='cuda:0')
# Epoch:  220  | Loss:  tensor(9.0581, device='cuda:0')  | Accuracy:  tensor(0.9264, device='cuda:0')
# Epoch:  230  | Loss:  tensor(8.8317, device='cuda:0')  | Accuracy:  tensor(0.9287, device='cuda:0')
# Epoch:  240  | Loss:  tensor(8.5651, device='cuda:0')  | Accuracy:  tensor(0.9291, device='cuda:0')
# Epoch:  250  | Loss:  tensor(8.3771, device='cuda:0')  | Accuracy:  tensor(0.9309, device='cuda:0')
# Epoch:  260  | Loss:  tensor(8.0540, device='cuda:0')  | Accuracy:  tensor(0.9336, device='cuda:0')
# Epoch:  270  | Loss:  tensor(7.9741, device='cuda:0')  | Accuracy:  tensor(0.9322, device='cuda:0')
# Epoch:  280  | Loss:  tensor(7.8069, device='cuda:0')  | Accuracy:  tensor(0.9330, device='cuda:0')
# Epoch:  290  | Loss:  tensor(7.5689, device='cuda:0')  | Accuracy:  tensor(0.9343, device='cuda:0')
# Epoch:  300  | Loss:  tensor(7.3687, device='cuda:0')  | Accuracy:  tensor(0.9368, device='cuda:0')
# Epoch:  310  | Loss:  tensor(7.2220, device='cuda:0')  | Accuracy:  tensor(0.9372, device='cuda:0')
# Epoch:  320  | Loss:  tensor(7.0832, device='cuda:0')  | Accuracy:  tensor(0.9399, device='cuda:0')
# Epoch:  330  | Loss:  tensor(6.9115, device='cuda:0')  | Accuracy:  tensor(0.9427, device='cuda:0')
# Epoch:  340  | Loss:  tensor(6.7421, device='cuda:0')  | Accuracy:  tensor(0.9412, device='cuda:0')
# Epoch:  350  | Loss:  tensor(6.6360, device='cuda:0')  | Accuracy:  tensor(0.9456, device='cuda:0')
# Epoch:  360  | Loss:  tensor(6.5200, device='cuda:0')  | Accuracy:  tensor(0.9426, device='cuda:0')
# Epoch:  370  | Loss:  tensor(6.3873, device='cuda:0')  | Accuracy:  tensor(0.9462, device='cuda:0')
# Epoch:  380  | Loss:  tensor(6.3092, device='cuda:0')  | Accuracy:  tensor(0.9475, device='cuda:0')
# Epoch:  390  | Loss:  tensor(6.2523, device='cuda:0')  | Accuracy:  tensor(0.9458, device='cuda:0')
# Epoch:  400  | Loss:  tensor(6.0860, device='cuda:0')  | Accuracy:  tensor(0.9458, device='cuda:0')
# Epoch:  410  | Loss:  tensor(5.9852, device='cuda:0')  | Accuracy:  tensor(0.9487, device='cuda:0')
# Epoch:  420  | Loss:  tensor(5.8824, device='cuda:0')  | Accuracy:  tensor(0.9508, device='cuda:0')
# Epoch:  430  | Loss:  tensor(5.8181, device='cuda:0')  | Accuracy:  tensor(0.9506, device='cuda:0')
# Epoch:  440  | Loss:  tensor(5.7399, device='cuda:0')  | Accuracy:  tensor(0.9488, device='cuda:0')
# Epoch:  450  | Loss:  tensor(5.6877, device='cuda:0')  | Accuracy:  tensor(0.9510, device='cuda:0')
# Epoch:  460  | Loss:  tensor(5.6191, device='cuda:0')  | Accuracy:  tensor(0.9508, device='cuda:0')
# Epoch:  470  | Loss:  tensor(5.5662, device='cuda:0')  | Accuracy:  tensor(0.9512, device='cuda:0')
# Epoch:  480  | Loss:  tensor(5.4608, device='cuda:0')  | Accuracy:  tensor(0.9519, device='cuda:0')
# Epoch:  490  | Loss:  tensor(5.3379, device='cuda:0')  | Accuracy:  tensor(0.9517, device='cuda:0')
# Epoch:  500  | Loss:  tensor(5.2899, device='cuda:0')  | Accuracy:  tensor(0.9531, device='cuda:0')
# Epoch:  510  | Loss:  tensor(5.2463, device='cuda:0')  | Accuracy:  tensor(0.9517, device='cuda:0')
# Epoch:  520  | Loss:  tensor(5.1819, device='cuda:0')  | Accuracy:  tensor(0.9506, device='cuda:0')
# Epoch:  530  | Loss:  tensor(5.1075, device='cuda:0')  | Accuracy:  tensor(0.9512, device='cuda:0')
# Epoch:  540  | Loss:  tensor(5.0605, device='cuda:0')  | Accuracy:  tensor(0.9540, device='cuda:0')
# Epoch:  550  | Loss:  tensor(5.0625, device='cuda:0')  | Accuracy:  tensor(0.9527, device='cuda:0')
# Epoch:  560  | Loss:  tensor(4.9737, device='cuda:0')  | Accuracy:  tensor(0.9538, device='cuda:0')
# Epoch:  570  | Loss:  tensor(4.9150, device='cuda:0')  | Accuracy:  tensor(0.9537, device='cuda:0')
# Epoch:  580  | Loss:  tensor(4.8565, device='cuda:0')  | Accuracy:  tensor(0.9567, device='cuda:0')
# Epoch:  590  | Loss:  tensor(4.8316, device='cuda:0')  | Accuracy:  tensor(0.9537, device='cuda:0')
# Epoch:  600  | Loss:  tensor(4.7937, device='cuda:0')  | Accuracy:  tensor(0.9558, device='cuda:0')
# Epoch:  610  | Loss:  tensor(4.7579, device='cuda:0')  | Accuracy:  tensor(0.9538, device='cuda:0')
# Epoch:  620  | Loss:  tensor(4.7061, device='cuda:0')  | Accuracy:  tensor(0.9565, device='cuda:0')
# Epoch:  630  | Loss:  tensor(4.6378, device='cuda:0')  | Accuracy:  tensor(0.9563, device='cuda:0')
# Epoch:  640  | Loss:  tensor(4.5768, device='cuda:0')  | Accuracy:  tensor(0.9585, device='cuda:0')
# Epoch:  650  | Loss:  tensor(4.6016, device='cuda:0')  | Accuracy:  tensor(0.9554, device='cuda:0')
# Epoch:  660  | Loss:  tensor(4.5378, device='cuda:0')  | Accuracy:  tensor(0.9581, device='cuda:0')
# Epoch:  670  | Loss:  tensor(4.5119, device='cuda:0')  | Accuracy:  tensor(0.9579, device='cuda:0')
# Epoch:  680  | Loss:  tensor(4.4821, device='cuda:0')  | Accuracy:  tensor(0.9590, device='cuda:0')
# Epoch:  690  | Loss:  tensor(4.4266, device='cuda:0')  | Accuracy:  tensor(0.9558, device='cuda:0')
# Epoch:  700  | Loss:  tensor(4.4198, device='cuda:0')  | Accuracy:  tensor(0.9571, device='cuda:0')
# Epoch:  710  | Loss:  tensor(4.4106, device='cuda:0')  | Accuracy:  tensor(0.9579, device='cuda:0')
# Epoch:  720  | Loss:  tensor(4.3350, device='cuda:0')  | Accuracy:  tensor(0.9587, device='cuda:0')
# Epoch:  730  | Loss:  tensor(4.3757, device='cuda:0')  | Accuracy:  tensor(0.9585, device='cuda:0')
# Epoch:  740  | Loss:  tensor(4.3301, device='cuda:0')  | Accuracy:  tensor(0.9594, device='cuda:0')
# Epoch:  750  | Loss:  tensor(4.2778, device='cuda:0')  | Accuracy:  tensor(0.9585, device='cuda:0')
# Epoch:  760  | Loss:  tensor(4.2721, device='cuda:0')  | Accuracy:  tensor(0.9588, device='cuda:0')
# Epoch:  770  | Loss:  tensor(4.2136, device='cuda:0')  | Accuracy:  tensor(0.9577, device='cuda:0')
# Epoch:  780  | Loss:  tensor(4.1856, device='cuda:0')  | Accuracy:  tensor(0.9588, device='cuda:0')
# Epoch:  790  | Loss:  tensor(4.1948, device='cuda:0')  | Accuracy:  tensor(0.9585, device='cuda:0')
# Epoch:  800  | Loss:  tensor(4.1944, device='cuda:0')  | Accuracy:  tensor(0.9594, device='cuda:0')
# Epoch:  810  | Loss:  tensor(4.1769, device='cuda:0')  | Accuracy:  tensor(0.9588, device='cuda:0')
# Epoch:  820  | Loss:  tensor(4.1610, device='cuda:0')  | Accuracy:  tensor(0.9588, device='cuda:0')
# Epoch:  830  | Loss:  tensor(4.1325, device='cuda:0')  | Accuracy:  tensor(0.9592, device='cuda:0')
# Epoch:  840  | Loss:  tensor(4.0931, device='cuda:0')  | Accuracy:  tensor(0.9600, device='cuda:0')
# Epoch:  850  | Loss:  tensor(4.0991, device='cuda:0')  | Accuracy:  tensor(0.9588, device='cuda:0')
# Epoch:  860  | Loss:  tensor(4.0913, device='cuda:0')  | Accuracy:  tensor(0.9610, device='cuda:0')
# Epoch:  870  | Loss:  tensor(4.0358, device='cuda:0')  | Accuracy:  tensor(0.9600, device='cuda:0')
# Epoch:  880  | Loss:  tensor(4.0127, device='cuda:0')  | Accuracy:  tensor(0.9602, device='cuda:0')
# Epoch:  890  | Loss:  tensor(4.0579, device='cuda:0')  | Accuracy:  tensor(0.9587, device='cuda:0')
# Epoch:  900  | Loss:  tensor(4.0270, device='cuda:0')  | Accuracy:  tensor(0.9612, device='cuda:0')
# Epoch:  910  | Loss:  tensor(4.0472, device='cuda:0')  | Accuracy:  tensor(0.9581, device='cuda:0')
# Epoch:  920  | Loss:  tensor(3.9851, device='cuda:0')  | Accuracy:  tensor(0.9598, device='cuda:0')
# Epoch:  930  | Loss:  tensor(3.9605, device='cuda:0')  | Accuracy:  tensor(0.9613, device='cuda:0')
# Epoch:  940  | Loss:  tensor(3.9438, device='cuda:0')  | Accuracy:  tensor(0.9617, device='cuda:0')
# Epoch:  950  | Loss:  tensor(3.9330, device='cuda:0')  | Accuracy:  tensor(0.9631, device='cuda:0')
# Epoch:  960  | Loss:  tensor(3.9188, device='cuda:0')  | Accuracy:  tensor(0.9612, device='cuda:0')
# Epoch:  970  | Loss:  tensor(3.9357, device='cuda:0')  | Accuracy:  tensor(0.9612, device='cuda:0')
# Epoch:  980  | Loss:  tensor(3.8626, device='cuda:0')  | Accuracy:  tensor(0.9602, device='cuda:0')
# Epoch:  990  | Loss:  tensor(3.8406, device='cuda:0')  | Accuracy:  tensor(0.9598, device='cuda:0')
# Epoch:  1000  | Loss:  tensor(3.8146, device='cuda:0')  | Accuracy:  tensor(0.9613, device='cuda:0')
# Train Finished
# Training:  mfcc_m_1000_dr0.5_wc1e-05_lr1e-06.pt
# Epoch:  10  | Loss:  tensor(46.3373, device='cuda:0')  | Accuracy:  tensor(0.4967, device='cuda:0')
# Epoch:  20  | Loss:  tensor(45.8145, device='cuda:0')  | Accuracy:  tensor(0.5379, device='cuda:0')
# Epoch:  30  | Loss:  tensor(45.7467, device='cuda:0')  | Accuracy:  tensor(0.5561, device='cuda:0')
# Epoch:  40  | Loss:  tensor(45.5537, device='cuda:0')  | Accuracy:  tensor(0.5829, device='cuda:0')
# Epoch:  50  | Loss:  tensor(45.4918, device='cuda:0')  | Accuracy:  tensor(0.6005, device='cuda:0')
# Epoch:  60  | Loss:  tensor(45.3958, device='cuda:0')  | Accuracy:  tensor(0.6175, device='cuda:0')
# Epoch:  70  | Loss:  tensor(45.1628, device='cuda:0')  | Accuracy:  tensor(0.6350, device='cuda:0')
# Epoch:  80  | Loss:  tensor(44.9698, device='cuda:0')  | Accuracy:  tensor(0.6506, device='cuda:0')
# Epoch:  90  | Loss:  tensor(44.6059, device='cuda:0')  | Accuracy:  tensor(0.6663, device='cuda:0')
# Epoch:  100  | Loss:  tensor(44.1542, device='cuda:0')  | Accuracy:  tensor(0.6811, device='cuda:0')
# Epoch:  110  | Loss:  tensor(43.5766, device='cuda:0')  | Accuracy:  tensor(0.6940, device='cuda:0')
# Epoch:  120  | Loss:  tensor(42.8657, device='cuda:0')  | Accuracy:  tensor(0.7081, device='cuda:0')
# Epoch:  130  | Loss:  tensor(42.1238, device='cuda:0')  | Accuracy:  tensor(0.7191, device='cuda:0')
# Epoch:  140  | Loss:  tensor(41.2386, device='cuda:0')  | Accuracy:  tensor(0.7299, device='cuda:0')
# Epoch:  150  | Loss:  tensor(40.3109, device='cuda:0')  | Accuracy:  tensor(0.7401, device='cuda:0')
# Epoch:  160  | Loss:  tensor(39.3582, device='cuda:0')  | Accuracy:  tensor(0.7491, device='cuda:0')
# Epoch:  170  | Loss:  tensor(38.4241, device='cuda:0')  | Accuracy:  tensor(0.7538, device='cuda:0')
# Epoch:  180  | Loss:  tensor(37.4088, device='cuda:0')  | Accuracy:  tensor(0.7621, device='cuda:0')
# Epoch:  190  | Loss:  tensor(36.4548, device='cuda:0')  | Accuracy:  tensor(0.7678, device='cuda:0')
# Epoch:  200  | Loss:  tensor(35.5965, device='cuda:0')  | Accuracy:  tensor(0.7749, device='cuda:0')
# Epoch:  210  | Loss:  tensor(34.6367, device='cuda:0')  | Accuracy:  tensor(0.7780, device='cuda:0')
# Epoch:  220  | Loss:  tensor(33.7205, device='cuda:0')  | Accuracy:  tensor(0.7841, device='cuda:0')
# Epoch:  230  | Loss:  tensor(32.8178, device='cuda:0')  | Accuracy:  tensor(0.7927, device='cuda:0')
# Epoch:  240  | Loss:  tensor(32.0321, device='cuda:0')  | Accuracy:  tensor(0.7967, device='cuda:0')
# Epoch:  250  | Loss:  tensor(31.2974, device='cuda:0')  | Accuracy:  tensor(0.8023, device='cuda:0')
# Epoch:  260  | Loss:  tensor(30.5539, device='cuda:0')  | Accuracy:  tensor(0.8067, device='cuda:0')
# Epoch:  270  | Loss:  tensor(29.8805, device='cuda:0')  | Accuracy:  tensor(0.8104, device='cuda:0')
# Epoch:  280  | Loss:  tensor(29.1641, device='cuda:0')  | Accuracy:  tensor(0.8140, device='cuda:0')
# Epoch:  290  | Loss:  tensor(28.5390, device='cuda:0')  | Accuracy:  tensor(0.8185, device='cuda:0')
# Epoch:  300  | Loss:  tensor(27.9727, device='cuda:0')  | Accuracy:  tensor(0.8208, device='cuda:0')
# Epoch:  310  | Loss:  tensor(27.3781, device='cuda:0')  | Accuracy:  tensor(0.8260, device='cuda:0')
# Epoch:  320  | Loss:  tensor(26.8104, device='cuda:0')  | Accuracy:  tensor(0.8288, device='cuda:0')
# Epoch:  330  | Loss:  tensor(26.2350, device='cuda:0')  | Accuracy:  tensor(0.8319, device='cuda:0')
# Epoch:  340  | Loss:  tensor(25.7442, device='cuda:0')  | Accuracy:  tensor(0.8352, device='cuda:0')
# Epoch:  350  | Loss:  tensor(25.2627, device='cuda:0')  | Accuracy:  tensor(0.8375, device='cuda:0')
# Epoch:  360  | Loss:  tensor(24.8069, device='cuda:0')  | Accuracy:  tensor(0.8400, device='cuda:0')
# Epoch:  370  | Loss:  tensor(24.3586, device='cuda:0')  | Accuracy:  tensor(0.8442, device='cuda:0')
# Epoch:  380  | Loss:  tensor(24.0342, device='cuda:0')  | Accuracy:  tensor(0.8473, device='cuda:0')
# Epoch:  390  | Loss:  tensor(23.6005, device='cuda:0')  | Accuracy:  tensor(0.8498, device='cuda:0')
# Epoch:  400  | Loss:  tensor(23.1504, device='cuda:0')  | Accuracy:  tensor(0.8536, device='cuda:0')
# Epoch:  410  | Loss:  tensor(22.8450, device='cuda:0')  | Accuracy:  tensor(0.8556, device='cuda:0')
# Epoch:  420  | Loss:  tensor(22.4870, device='cuda:0')  | Accuracy:  tensor(0.8588, device='cuda:0')
# Epoch:  430  | Loss:  tensor(22.1561, device='cuda:0')  | Accuracy:  tensor(0.8611, device='cuda:0')
# Epoch:  440  | Loss:  tensor(21.8551, device='cuda:0')  | Accuracy:  tensor(0.8635, device='cuda:0')
# Epoch:  450  | Loss:  tensor(21.6019, device='cuda:0')  | Accuracy:  tensor(0.8656, device='cuda:0')
# Epoch:  460  | Loss:  tensor(21.2436, device='cuda:0')  | Accuracy:  tensor(0.8677, device='cuda:0')
# Epoch:  470  | Loss:  tensor(20.9788, device='cuda:0')  | Accuracy:  tensor(0.8692, device='cuda:0')
# Epoch:  480  | Loss:  tensor(20.7265, device='cuda:0')  | Accuracy:  tensor(0.8708, device='cuda:0')
# Epoch:  490  | Loss:  tensor(20.4514, device='cuda:0')  | Accuracy:  tensor(0.8740, device='cuda:0')
# Epoch:  500  | Loss:  tensor(20.1953, device='cuda:0')  | Accuracy:  tensor(0.8748, device='cuda:0')
# Epoch:  510  | Loss:  tensor(19.9672, device='cuda:0')  | Accuracy:  tensor(0.8758, device='cuda:0')
# Epoch:  520  | Loss:  tensor(19.7501, device='cuda:0')  | Accuracy:  tensor(0.8765, device='cuda:0')
# Epoch:  530  | Loss:  tensor(19.4712, device='cuda:0')  | Accuracy:  tensor(0.8773, device='cuda:0')
# Epoch:  540  | Loss:  tensor(19.2880, device='cuda:0')  | Accuracy:  tensor(0.8781, device='cuda:0')
# Epoch:  550  | Loss:  tensor(19.0633, device='cuda:0')  | Accuracy:  tensor(0.8783, device='cuda:0')
# Epoch:  560  | Loss:  tensor(18.8504, device='cuda:0')  | Accuracy:  tensor(0.8792, device='cuda:0')
# Epoch:  570  | Loss:  tensor(18.6918, device='cuda:0')  | Accuracy:  tensor(0.8815, device='cuda:0')
# Epoch:  580  | Loss:  tensor(18.4738, device='cuda:0')  | Accuracy:  tensor(0.8819, device='cuda:0')
# Epoch:  590  | Loss:  tensor(18.2620, device='cuda:0')  | Accuracy:  tensor(0.8833, device='cuda:0')
# Epoch:  600  | Loss:  tensor(18.1539, device='cuda:0')  | Accuracy:  tensor(0.8840, device='cuda:0')
# Epoch:  610  | Loss:  tensor(17.9691, device='cuda:0')  | Accuracy:  tensor(0.8850, device='cuda:0')
# Epoch:  620  | Loss:  tensor(17.8104, device='cuda:0')  | Accuracy:  tensor(0.8886, device='cuda:0')
# Epoch:  630  | Loss:  tensor(17.6419, device='cuda:0')  | Accuracy:  tensor(0.8882, device='cuda:0')
# Epoch:  640  | Loss:  tensor(17.5066, device='cuda:0')  | Accuracy:  tensor(0.8883, device='cuda:0')
# Epoch:  650  | Loss:  tensor(17.3413, device='cuda:0')  | Accuracy:  tensor(0.8909, device='cuda:0')
# Epoch:  660  | Loss:  tensor(17.1717, device='cuda:0')  | Accuracy:  tensor(0.8914, device='cuda:0')
# Epoch:  670  | Loss:  tensor(17.0476, device='cuda:0')  | Accuracy:  tensor(0.8922, device='cuda:0')
# Epoch:  680  | Loss:  tensor(16.8718, device='cuda:0')  | Accuracy:  tensor(0.8926, device='cuda:0')
# Epoch:  690  | Loss:  tensor(16.7421, device='cuda:0')  | Accuracy:  tensor(0.8943, device='cuda:0')
# Epoch:  700  | Loss:  tensor(16.5715, device='cuda:0')  | Accuracy:  tensor(0.8969, device='cuda:0')
# Epoch:  710  | Loss:  tensor(16.4392, device='cuda:0')  | Accuracy:  tensor(0.8981, device='cuda:0')
# Epoch:  720  | Loss:  tensor(16.3340, device='cuda:0')  | Accuracy:  tensor(0.9002, device='cuda:0')
# Epoch:  730  | Loss:  tensor(16.2128, device='cuda:0')  | Accuracy:  tensor(0.9013, device='cuda:0')
# Epoch:  740  | Loss:  tensor(16.0481, device='cuda:0')  | Accuracy:  tensor(0.9010, device='cuda:0')
# Epoch:  750  | Loss:  tensor(15.9235, device='cuda:0')  | Accuracy:  tensor(0.9019, device='cuda:0')
# Epoch:  760  | Loss:  tensor(15.8432, device='cuda:0')  | Accuracy:  tensor(0.9029, device='cuda:0')
# Epoch:  770  | Loss:  tensor(15.6957, device='cuda:0')  | Accuracy:  tensor(0.9035, device='cuda:0')
# Epoch:  780  | Loss:  tensor(15.5813, device='cuda:0')  | Accuracy:  tensor(0.9031, device='cuda:0')
# Epoch:  790  | Loss:  tensor(15.4815, device='cuda:0')  | Accuracy:  tensor(0.9058, device='cuda:0')
# Epoch:  800  | Loss:  tensor(15.3656, device='cuda:0')  | Accuracy:  tensor(0.9060, device='cuda:0')
# Epoch:  810  | Loss:  tensor(15.2695, device='cuda:0')  | Accuracy:  tensor(0.9058, device='cuda:0')
# Epoch:  820  | Loss:  tensor(15.1565, device='cuda:0')  | Accuracy:  tensor(0.9063, device='cuda:0')
# Epoch:  830  | Loss:  tensor(15.0179, device='cuda:0')  | Accuracy:  tensor(0.9069, device='cuda:0')
# Epoch:  840  | Loss:  tensor(14.9088, device='cuda:0')  | Accuracy:  tensor(0.9065, device='cuda:0')
# Epoch:  850  | Loss:  tensor(14.7856, device='cuda:0')  | Accuracy:  tensor(0.9073, device='cuda:0')
# Epoch:  860  | Loss:  tensor(14.7009, device='cuda:0')  | Accuracy:  tensor(0.9079, device='cuda:0')
# Epoch:  870  | Loss:  tensor(14.6320, device='cuda:0')  | Accuracy:  tensor(0.9071, device='cuda:0')
# Epoch:  880  | Loss:  tensor(14.5189, device='cuda:0')  | Accuracy:  tensor(0.9075, device='cuda:0')
# Epoch:  890  | Loss:  tensor(14.3980, device='cuda:0')  | Accuracy:  tensor(0.9077, device='cuda:0')
# Epoch:  900  | Loss:  tensor(14.3241, device='cuda:0')  | Accuracy:  tensor(0.9090, device='cuda:0')
# Epoch:  910  | Loss:  tensor(14.1799, device='cuda:0')  | Accuracy:  tensor(0.9092, device='cuda:0')
# Epoch:  920  | Loss:  tensor(14.1226, device='cuda:0')  | Accuracy:  tensor(0.9102, device='cuda:0')
# Epoch:  930  | Loss:  tensor(14.0189, device='cuda:0')  | Accuracy:  tensor(0.9108, device='cuda:0')
# Epoch:  940  | Loss:  tensor(13.9373, device='cuda:0')  | Accuracy:  tensor(0.9117, device='cuda:0')
# Epoch:  950  | Loss:  tensor(13.8537, device='cuda:0')  | Accuracy:  tensor(0.9117, device='cuda:0')
# Epoch:  960  | Loss:  tensor(13.7647, device='cuda:0')  | Accuracy:  tensor(0.9113, device='cuda:0')
# Epoch:  970  | Loss:  tensor(13.6664, device='cuda:0')  | Accuracy:  tensor(0.9121, device='cuda:0')
# Epoch:  980  | Loss:  tensor(13.5805, device='cuda:0')  | Accuracy:  tensor(0.9123, device='cuda:0')
# Epoch:  990  | Loss:  tensor(13.4812, device='cuda:0')  | Accuracy:  tensor(0.9137, device='cuda:0')
# Epoch:  1000  | Loss:  tensor(13.3998, device='cuda:0')  | Accuracy:  tensor(0.9137, device='cuda:0')
# Train Finished
# Training:  mfcc_m_1000_dr0.75_wc1e-05_lr0.0001.pt
# Epoch:  1  == Early stop due to an increase in validation loss
# Train Finished
# Training:  mfcc_m_1000_dr0.75_wc1e-05_lr1e-05.pt
# Epoch:  7  == Early stop due to an increase in validation loss
# Train Finished
# Training:  mfcc_m_1000_dr0.75_wc1e-05_lr1e-06.pt
# Epoch:  10  | Loss:  tensor(43.7886, device='cuda:0')  | Accuracy:  tensor(0.6635, device='cuda:0')
# Epoch:  20  | Loss:  tensor(44.1580, device='cuda:0')  | Accuracy:  tensor(0.6618, device='cuda:0')
# Epoch:  30  | Loss:  tensor(44.6871, device='cuda:0')  | Accuracy:  tensor(0.6603, device='cuda:0')
# Epoch:  40  | Loss:  tensor(45.5156, device='cuda:0')  | Accuracy:  tensor(0.6583, device='cuda:0')
# Epoch:  50  | Loss:  tensor(46.3246, device='cuda:0')  | Accuracy:  tensor(0.6535, device='cuda:0')
# Epoch:  60  | Loss:  tensor(47.2319, device='cuda:0')  | Accuracy:  tensor(0.6484, device='cuda:0')
# Epoch:  70  | Loss:  tensor(48.0051, device='cuda:0')  | Accuracy:  tensor(0.6474, device='cuda:0')
# Epoch:  71  == Early stop due to an increase in validation loss
# Train Finished
# Training:  mfcc_m_1000_dr0.9_wc1e-05_lr0.0001.pt
# Epoch:  3  == Early stop due to an increase in validation loss
# Train Finished
# Training:  mfcc_m_1000_dr0.9_wc1e-05_lr1e-05.pt
# Epoch:  8  == Early stop due to an increase in validation loss
# Train Finished
# Training:  mfcc_m_1000_dr0.9_wc1e-05_lr1e-06.pt
# Epoch:  10  | Loss:  tensor(42.1945, device='cuda:0')  | Accuracy:  tensor(0.6643, device='cuda:0')
# Epoch:  20  | Loss:  tensor(41.5970, device='cuda:0')  | Accuracy:  tensor(0.6689, device='cuda:0')
# Epoch:  30  | Loss:  tensor(42.2241, device='cuda:0')  | Accuracy:  tensor(0.6693, device='cuda:0')
# Epoch:  40  | Loss:  tensor(43.1330, device='cuda:0')  | Accuracy:  tensor(0.6693, device='cuda:0')
# Epoch:  50  | Loss:  tensor(44.0450, device='cuda:0')  | Accuracy:  tensor(0.6693, device='cuda:0')
# Epoch:  60  | Loss:  tensor(45.0214, device='cuda:0')  | Accuracy:  tensor(0.6689, device='cuda:0')
# Epoch:  65  == Early stop due to an increase in validation loss
# Train Finished

# %%
len([x for x in y_train if x == 8])
# Out:
# 7881
