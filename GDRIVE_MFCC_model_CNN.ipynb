# %% [markdown]
# Create a model using built-in library from Pytorch.
# This code closely follows nn_tutorial notebook.

# %%
import os
from google.colab import drive
drive.mount('/content/gdrive')
# !pwd
os.chdir('gdrive/My Drive/PyHack2019/')
# !pwd
# !ls
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content
# /content/gdrive/My Drive/PyHack2019
# mfcc_noise_attr.pkl  mix_chroma_tar.pkl  model	 TEST_S_X_ATT.pkl
# mfcc_noise_tar.pkl   mix_mfcc_attr.pkl	 result  TEST_S_X_TAR.pkl
# mix_chroma_attr.pkl  mix_mfcc_tar.pkl	 TEST

# %%
import csv, torch, math, os, pickle
from torch import nn
from torch import optim
import torch.nn.functional as F

global chroma_shape, epochs, train_bs, validate_bs, lr, n_class

if torch.cuda.is_available():
  device = 'cuda'
else:
  device = 'cpu'
  
print(device)
# Out:
# cuda

# %%
## read attr and tar in .pkl files
## Param: ratio = training size to the sample size. 
##         E.g. 0.7 means using 70% of the samples as training 
##              sample and the rest as validation sample. 
## Return: (1) a list of padded attr arrays
##         (2) a list of paddrd tar arrays
def read_data(ratio):
    
    assert (ratio > 0 and ratio < 1), 'Invalid ratio'
    
    
    att_file = open(r'mfcc_noise_attr.pkl', 'rb')
    x_train = pickle.load(att_file)  
    att_file.close()
    
    tar_file = open(r'mfcc_noise_tar.pkl', 'rb')
    str_y_train = pickle.load(tar_file)
    tar_file.close()
    
    y = torch.tensor([0 if s == 's' else (1 if s == 'x' else 2) for s in str_y_train])
    assert (len(x_train) == len(y)), 'Unequal sample lengths'
    
    #print([(x,s) for x, s in zip(str_y_train, y_train)])
    
    ## need .float so that it has the same type as weights in the model
    #return torch.tensor(x_train).float(), y_train
    #print(x_train[0].shape, x_train[1].shape, x_train[2].shape)
    #print(x_train[len(x_train)-2].shape)
    x = torch.tensor(x_train).float() 
    divider = int(len(y)*ratio)
    
    
    x_train = x[:divider, :, :]
    y_train = y[:divider]
    
    print(x_train.shape, x.shape)

    x_validate = x[divider:, :, :]
    y_validate = y[divider:]

    assert (x_train.shape[0] + x_validate.shape[0] == len(y_train) + len(y_validate)), 'Lengths do not add up'

    return x_train, y_train, x_validate, y_validate

# %%
x_train, y_train, x_validate, y_validate = read_data(0.7)

x_train = x_train.to(device)
y_train = y_train.to(device)
x_validate = x_validate.to(device)
y_validate = y_validate.to(device)

print (x_train.device)
# Out:
# torch.Size([11709, 13, 239]) torch.Size([16728, 13, 239])
# cuda:0

# %%
x_train.shape
# Out:
# torch.Size([11709, 13, 239])

# %%
def accuracy(out, yb):
    ##get the index with the max
    preds = torch.argmax(out, dim = 1)
    return (preds == yb).float().mean()

# %%
## Get the shape of a padded instance for model construction
chroma_shape = x_train[0].shape

#epochs = 50
#train_bs = 20
#validate_bs = train_bs*2
n_train = x_train.shape[0]
n_validate = x_validate.shape[0]
n_class = 3

loss_func = F.cross_entropy

# %% [markdown]
# Since there are three classes, we set D_out to 3. n is total number of instances and c is the number of attributes in each instance. We use a loss function from torch.nn.functional.

# %%
## 13*239
class SoundRecognition_CNN(nn.Module):
  
    def __init__(self, dropout_rate):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=0)
        self.conv2 = nn.Conv2d(16, 16, kernel_size=3, stride=1, padding=0)
        self.conv3 = nn.Conv2d(16, 16, kernel_size=3, stride=1, padding=0)
        
        self.dropout = nn.Dropout(p = dropout_rate)
        
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = torch.nn.Linear(16*3*116, n_class)

    def forward(self, xb):
        #print(type(xb), len(xb))
        
        ## input of size (bs, 1, 12, 60)
        xb = xb.view(-1, 1, chroma_shape[0], chroma_shape[1])
        #print('xb shape', xb.shape)
        
        ## (bs, 1, 12, 60) >> (bs, 16, 10, 58)
        xb = self.dropout(F.relu(self.conv1(xb)))
        #print('---xb shape2', xb.shape)
        
        ## (bs, 16, 10, 58) >> (bs, 16, 8, 56)
        xb = self.dropout(F.relu(self.conv2(xb)))
        #print('---xb shape3', xb.shape)
        
        ## (bs, 16, 8, 56) >> (bs, 16, 6, 54)
        xb = self.dropout(F.relu(self.conv3(xb)))
        #print('---xb shape4', xb.shape)
        
        ## (bs, 16, 6, 54) >> (bs, 16, 3, 27)
        xb = self.pool(xb)
        #print('---xb shape5', xb.shape)
        #print('sh', xb.shape)
        ## reshape for fully connected
        #xb = xb.view(-1, 16*3*27)
        xb = xb.view(-1, 16*3*116)
        
        ## (bs, 16*3*27) >> (bs, 3)
        xb = self.fc1(xb)
        #print('---xb shape6', xb.shape)
        #print('=====', xb.shape)
        return xb.view(-1, xb.size(1))

## Get the model and optim object that will be used to update model parameters
def get_model(dropout_rate, weight_decay, lr):
    model = SoundRecognition_CNN(dropout_rate)
    return model, optim.Adam(model.parameters(), weight_decay = weight_decay, lr = lr)

# %%
def validate(trained_model, validate_bs, n_validate):
    trained_model.eval()
    loss = []
    acc = []
    with torch.no_grad():

        for i in range((n_validate - 1) // validate_bs + 1):
            start_i = i * validate_bs
            end_i = start_i + validate_bs
            #print(xb.shape)
            xb = x_validate[start_i:end_i, :, :]
            yb = y_validate[start_i:end_i]
            pred = trained_model(xb)
            loss.append(loss_func(pred, yb))
            acc.append(accuracy(pred, yb))

        #print(loss)
        valid_loss = sum(loss)
    return valid_loss, sum(acc)/len(acc)

# %%
def fit(epochs = 100, 
        train_bs = 10, 
        n_train = n_train, 
        validate_bs = 20, 
        n_validate = n_validate,
        dropout_rate = 0.5, 
        weight_decay = 1e-6, 
        lr = 1e-4,
        tolerance = 0.05):
  
  
  model, opt = get_model(dropout_rate = dropout_rate, weight_decay = weight_decay, lr = lr)
  model.to(device)
  
  ## to save training progress
  text_file = ''
  prev_small_vl = 10000000
  for epoch in range(epochs):

      #print('Training')
      model.train()
      for i in range((n_train - 1) // train_bs + 1):

          start_i = i * train_bs
          end_i = start_i + train_bs
          xb = x_train[start_i:end_i, :, :]
          yb = y_train[start_i:end_i]
          pred = model(xb)
          #print('pred: ', pred, ' | yb: ', yb)
          loss = loss_func(pred, yb)

          loss.backward()
          opt.step()
          opt.zero_grad()

      valid_loss, acc = validate(model, validate_bs, n_validate)
      
      ##early stop
      if valid_loss < prev_small_vl:
        prev_small_vl = valid_loss
      elif valid_loss > prev_small_vl*(1+tolerance):
        print('Epoch: ', epoch, ' == Early stop due to an increase in validation loss')
        break
      

      if (epoch + 1)% 10 == 0:
          print('Epoch: ', epoch + 1, ' | Loss: ', valid_loss, ' | Accuracy: ', acc)
          text_file = text_file + 'Epoch: '+ str(epoch + 1) + ' | Loss: ' + str(valid_loss) + ' | Accuracy: ' + str(acc) + '\n'
  text_file = str(model) + '\n\n' + text_file
  print('Train Finished')
  return model, text_file

# %%
# m, t = fit(epochs = 20, 
#     train_bs = 10, 
#     n_train = n_train, 
#     validate_bs = 20, 
#     n_validate = n_validate,
#     dropout_rate = 0.5, 
#     weight_decay = 1e-6, 
#     lr = 1e-4)

# %%
def getName(epochs, dropout_rate, weight_decay, lr):
  
  name = 'mfcc_m_' + str(epochs) + '_dr' + str(dropout_rate) + '_wc' + str(weight_decay) + '_lr' + str(try_lr)
  return name +'.pt', name +'.txt'

# %%
m, t_file = fit(epochs = 500, 
                train_bs = 100, 
                n_train = n_train, 
                validate_bs = 200, 
                n_validate = n_validate,
                dropout_rate = 0.5, 
                weight_decay = 0.01, 
                lr = 1e-5,
                tolerance = 0.05)
# Out:
# Epoch:  9  == Early Stop due to an increase in validation loss
# Train Finished

# %%
#torch.save(m, model_dir + m_save_path)

torch.save(m, 'model/early_stop_mfcc_noise_trained.pt')
file = open('model/early_stop_mfcc_noise_trained.txt',"w") 
file.write(t_file)
file.close()
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:256: UserWarning: Couldn't retrieve source code for container of type SoundRecognition_CNN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
###### Make change under this this line########

###############################################


### run model with several sets of hyperparameters
### the models and training results are saved

model_dir = 'model/'
result_dir = 'result/'



wc_list = [1e-3, 1e-4, 1e-5]
dr_list = [0.75, 0.9] #[0, 0.1, 0.5, 0.75, 0.9] do dr of 0, 0.1, 0.5,  with wc of 1e-4, 1e-5 and all lr
lr_list = [1e-4, 1e-5, 1e-6]
epochs = 1000
#dropout_rate = 0.5
#weight_decay = 1e-6

for try_wc in wc_list:
  for try_dr in dr_list:
    for try_lr in lr_list:
      m_save_path, f_save_path = getName(epochs, try_dr, try_wc, try_lr)
      print('Training: ', m_save_path)
      m, t_file = fit(epochs = epochs, 
                      train_bs = 100, 
                      n_train = n_train, 
                      validate_bs = 200, 
                      n_validate = n_validate,
                      dropout_rate = try_dr, 
                      weight_decay = try_wc, 
                      lr = try_lr)

      torch.save(m, model_dir + m_save_path)
      file = open(result_dir + f_save_path,"w") 
      file.write(t_file)
      file.close()
# Out:
# Training:  mfcc_m_1000_dr0.75_wc0.001_lr0.0001.pt
# Epoch:  10  | Loss:  tensor(14.4796, device='cuda:0')  | Accuracy:  tensor(0.8349, device='cuda:0')
# Epoch:  20  | Loss:  tensor(14.9914, device='cuda:0')  | Accuracy:  tensor(0.8552, device='cuda:0')
# Epoch:  30  | Loss:  tensor(14.0225, device='cuda:0')  | Accuracy:  tensor(0.8456, device='cuda:0')
# Epoch:  40  | Loss:  tensor(11.7950, device='cuda:0')  | Accuracy:  tensor(0.8810, device='cuda:0')
# Epoch:  600  | Loss:  tensor(4.0602, device='cuda:0')  | Accuracy:  tensor(0.9503, device='cuda:0')
# Epoch:  610  | Loss:  tensor(4.0061, device='cuda:0')  | Accuracy:  tensor(0.9524, device='cuda:0')
# Epoch:  620  | Loss:  tensor(3.8432, device='cuda:0')  | Accuracy:  tensor(0.9520, device='cuda:0')
# Epoch:  630  | Loss:  tensor(3.7473, device='cuda:0')  | Accuracy:  tensor(0.9530, device='cuda:0')
# Epoch:  640  | Loss:  tensor(3.7223, device='cuda:0')  | Accuracy:  tensor(0.9533, device='cuda:0')
# Epoch:  650  | Loss:  tensor(3.6354, device='cuda:0')  | Accuracy:  tensor(0.9522, device='cuda:0')
# Epoch:  660  | Loss:  tensor(3.5409, device='cuda:0')  | Accuracy:  tensor(0.9540, device='cuda:0')
# Epoch:  670  | Loss:  tensor(3.4231, device='cuda:0')  | Accuracy:  tensor(0.9564, device='cuda:0')
# Epoch:  680  | Loss:  tensor(3.3714, device='cuda:0')  | Accuracy:  tensor(0.9565, device='cuda:0')
# Epoch:  690  | Loss:  tensor(3.3169, device='cuda:0')  | Accuracy:  tensor(0.9570, device='cuda:0')
# Epoch:  700  | Loss:  tensor(3.2692, device='cuda:0')  | Accuracy:  tensor(0.9581, device='cuda:0')
# Epoch:  710  | Loss:  tensor(3.1317, device='cuda:0')  | Accuracy:  tensor(0.9588, device='cuda:0')
# Epoch:  720  | Loss:  tensor(3.0773, device='cuda:0')  | Accuracy:  tensor(0.9588, device='cuda:0')
# Epoch:  730  | Loss:  tensor(3.0454, device='cuda:0')  | Accuracy:  tensor(0.9580, device='cuda:0')
# Epoch:  740  | Loss:  tensor(2.9385, device='cuda:0')  | Accuracy:  tensor(0.9594, device='cuda:0')
# Epoch:  750  | Loss:  tensor(2.8455, device='cuda:0')  | Accuracy:  tensor(0.9615, device='cuda:0')
# Epoch:  760  | Loss:  tensor(2.8326, device='cuda:0')  | Accuracy:  tensor(0.9625, device='cuda:0')
# Epoch:  770  | Loss:  tensor(2.7832, device='cuda:0')  | Accuracy:  tensor(0.9624, device='cuda:0')
# Epoch:  780  | Loss:  tensor(2.6209, device='cuda:0')  | Accuracy:  tensor(0.9621, device='cuda:0')
# Epoch:  790  | Loss:  tensor(2.6646, device='cuda:0')  | Accuracy:  tensor(0.9618, device='cuda:0')
# Epoch:  800  | Loss:  tensor(2.6224, device='cuda:0')  | Accuracy:  tensor(0.9626, device='cuda:0')
# Epoch:  810  | Loss:  tensor(2.6002, device='cuda:0')  | Accuracy:  tensor(0.9632, device='cuda:0')
# Epoch:  820  | Loss:  tensor(2.5703, device='cuda:0')  | Accuracy:  tensor(0.9636, device='cuda:0')
# Epoch:  830  | Loss:  tensor(2.4918, device='cuda:0')  | Accuracy:  tensor(0.9632, device='cuda:0')
# Epoch:  840  | Loss:  tensor(2.4475, device='cuda:0')  | Accuracy:  tensor(0.9642, device='cuda:0')
# Epoch:  850  | Loss:  tensor(2.4489, device='cuda:0')  | Accuracy:  tensor(0.9646, device='cuda:0')
# Epoch:  860  | Loss:  tensor(2.3534, device='cuda:0')  | Accuracy:  tensor(0.9655, device='cuda:0')
# Epoch:  900  | Loss:  tensor(12.9722, device='cuda:0')  | Accuracy:  tensor(0.7789, device='cuda:0')
# Epoch:  910  | Loss:  tensor(12.9936, device='cuda:0')  | Accuracy:  tensor(0.7795, device='cuda:0')
# Epoch:  920  | Loss:  tensor(13.0030, device='cuda:0')  | Accuracy:  tensor(0.7810, device='cuda:0')
# Epoch:  930  | Loss:  tensor(13.0138, device='cuda:0')  | Accuracy:  tensor(0.7810, device='cuda:0')
# Epoch:  940  | Loss:  tensor(13.0451, device='cuda:0')  | Accuracy:  tensor(0.7806, device='cuda:0')
# Epoch:  950  | Loss:  tensor(13.0931, device='cuda:0')  | Accuracy:  tensor(0.7790, device='cuda:0')
# Epoch:  960  | Loss:  tensor(13.0909, device='cuda:0')  | Accuracy:  tensor(0.7811, device='cuda:0')
# Epoch:  970  | Loss:  tensor(13.1326, device='cuda:0')  | Accuracy:  tensor(0.7798, device='cuda:0')
# Epoch:  980  | Loss:  tensor(13.0984, device='cuda:0')  | Accuracy:  tensor(0.7814, device='cuda:0')
# Epoch:  990  | Loss:  tensor(13.1268, device='cuda:0')  | Accuracy:  tensor(0.7814, device='cuda:0')
# Epoch:  1000  | Loss:  tensor(13.1567, device='cuda:0')  | Accuracy:  tensor(0.7812, device='cuda:0')
# Train Finished
# Training:  mfcc_m_1000_dr0.9_wc0.001_lr0.0001.pt
# Epoch:  10  | Loss:  tensor(11.7897, device='cuda:0')  | Accuracy:  tensor(0.9251, device='cuda:0')
# Epoch:  20  | Loss:  tensor(15.2605, device='cuda:0')  | Accuracy:  tensor(0.8817, device='cuda:0')
# Epoch:  30  | Loss:  tensor(16.4338, device='cuda:0')  | Accuracy:  tensor(0.3993, device='cuda:0')
# Epoch:  40  | Loss:  tensor(16.7619, device='cuda:0')  | Accuracy:  tensor(0.0389, device='cuda:0')
# Epoch:  50  | Loss:  tensor(16.8976, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  60  | Loss:  tensor(16.9776, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  70  | Loss:  tensor(17.0545, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  80  | Loss:  tensor(17.1195, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  90  | Loss:  tensor(17.1926, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  100  | Loss:  tensor(17.2715, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  110  | Loss:  tensor(17.3438, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  120  | Loss:  tensor(17.4132, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  130  | Loss:  tensor(17.4755, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  140  | Loss:  tensor(17.5269, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  150  | Loss:  tensor(17.5789, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  160  | Loss:  tensor(17.6142, device='cuda:0')  | Accuracy:  tensor(0.0372, device='cuda:0')
# Epoch:  170  | Loss:  tensor(17.5833, device='cuda:0')  | Accuracy:  tensor(0.0412, device='cuda:0')
# Epoch:  180  | Loss:  tensor(17.3468, device='cuda:0')  | Accuracy:  tensor(0.0655, device='cuda:0')
# Epoch:  190  | Loss:  tensor(17.1031, device='cuda:0')  | Accuracy:  tensor(0.1175, device='cuda:0')
# Epoch:  200  | Loss:  tensor(16.8212, device='cuda:0')  | Accuracy:  tensor(0.1787, device='cuda:0')
# Epoch:  210  | Loss:  tensor(16.1332, device='cuda:0')  | Accuracy:  tensor(0.2994, device='cuda:0')
# Epoch:  220  | Loss:  tensor(15.4829, device='cuda:0')  | Accuracy:  tensor(0.3846, device='cuda:0')
device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  300  | Loss:  tensor(16.8802, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  310  | Loss:  tensor(16.8859, device='cuda:0')  | Accuracy:  tensor(0.0361, device='cuda:0')
# Epoch:  320  | Loss:  tensor(16.9009, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  330  | Loss:  tensor(16.9137, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  340  | Loss:  tensor(16.9223, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  350  | Loss:  tensor(16.9392, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  360  | Loss:  tensor(16.9456, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  370  | Loss:  tensor(16.9534, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  380  | Loss:  tensor(16.9674, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  390  | Loss:  tensor(16.9700, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  400  | Loss:  tensor(16.9852, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  410  | Loss:  tensor(16.9895, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  420  | Loss:  tensor(16.9995, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  430  | Loss:  tensor(17.0086, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  440  | Loss:  tensor(17.0193, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  450  | Loss:  tensor(17.0232, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  460  | Loss:  tensor(17.0353, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  470  | Loss:  tensor(17.0433, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  480  | Loss:  tensor(17.0545, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  490  | Loss:  tensor(17.0631, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  500  | Loss:  tensor(17.0771, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  510  | Loss:  tensor(17.0941, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  520  | Loss:  tensor(17.0990, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  530  | Loss:  tensor(17.0981, device='cuda:0')  | Accuracy:  tensor(0.0374, device='cuda:0')
# Epoch:  540  | Loss:  tensor(17.1055, device='cuda:0')  | Accuracy:  tensor(0.0381, device='cuda:0')
# Epoch:  550  | Loss:  tensor(17.1305, device='cuda:0')  | Accuracy:  tensor(0.0378, device='cuda:0')
# Epoch:  560  | Loss:  tensor(17.1302, device='cuda:0')  | Accuracy:  tensor(0.0381, device='cuda:0')
# Epoch:  570  | Loss:  tensor(17.1346, device='cuda:0')  | Accuracy:  tensor(0.0384, device='cuda:0')
# Epoch:  580  | Loss:  tensor(17.1572, device='cuda:0')  | Accuracy:  tensor(0.0374, device='cuda:0')
# Epoch:  590  | Loss:  tensor(17.1715, device='cuda:0')  | Accuracy:  tensor(0.0381, device='cuda:0')
# Epoch:  600  | Loss:  tensor(17.1672, device='cuda:0')  | Accuracy:  tensor(0.0414, device='cuda:0')
# Epoch:  610  | Loss:  tensor(17.1807, device='cuda:0')  | Accuracy:  tensor(0.0414, device='cuda:0')
# Epoch:  620  | Loss:  tensor(17.1910, device='cuda:0')  | Accuracy:  tensor(0.0411, device='cuda:0')
# Epoch:  630  | Loss:  tensor(17.2066, device='cuda:0')  | Accuracy:  tensor(0.0414, device='cuda:0')
# Epoch:  640  | Loss:  tensor(17.2210, device='cuda:0')  | Accuracy:  tensor(0.0411, device='cuda:0')
# Epoch:  650  | Loss:  tensor(17.2213, device='cuda:0')  | Accuracy:  tensor(0.0438, device='cuda:0')
# Epoch:  660  | Loss:  tensor(17.2365, device='cuda:0')  | Accuracy:  tensor(0.0448, device='cuda:0')
# Epoch:  670  | Loss:  tensor(17.2423, device='cuda:0')  | Accuracy:  tensor(0.0458, device='cuda:0')
# Epoch:  940  | Loss:  tensor(12.4121, device='cuda:0')  | Accuracy:  tensor(0.7991, device='cuda:0')
# Epoch:  950  | Loss:  tensor(12.4366, device='cuda:0')  | Accuracy:  tensor(0.7982, device='cuda:0')
# Epoch:  960  | Loss:  tensor(12.4723, device='cuda:0')  | Accuracy:  tensor(0.7969, device='cuda:0')
# Epoch:  970  | Loss:  tensor(12.4732, device='cuda:0')  | Accuracy:  tensor(0.7969, device='cuda:0')
# Epoch:  980  | Loss:  tensor(12.4902, device='cuda:0')  | Accuracy:  tensor(0.7948, device='cuda:0')
# Epoch:  990  | Loss:  tensor(12.4954, device='cuda:0')  | Accuracy:  tensor(0.7961, device='cuda:0')
# Epoch:  1000  | Loss:  tensor(12.5418, device='cuda:0')  | Accuracy:  tensor(0.7921, device='cuda:0')
# Train Finished
# Training:  mfcc_m_1000_dr0.9_wc0.0001_lr0.0001.pt
# Epoch:  10  | Loss:  tensor(12.5185, device='cuda:0')  | Accuracy:  tensor(0.9178, device='cuda:0')
# Epoch:  20  | Loss:  tensor(16.4041, device='cuda:0')  | Accuracy:  tensor(0.4041, device='cuda:0')
# Epoch:  30  | Loss:  tensor(16.9200, device='cuda:0')  | Accuracy:  tensor(0.0354, device='cuda:0')
# Epoch:  40  | Loss:  tensor(17.0623, device='cuda:0')  | Accuracy:  tensor(0.0368, device='cuda:0')
# Epoch:  50  | Loss:  tensor(17.1733, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  60  | Loss:  tensor(17.2686, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  70  | Loss:  tensor(17.3683, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  80  | Loss:  tensor(17.4626, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  90  | Loss:  tensor(17.5480, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  100  | Loss:  tensor(17.6170, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  110  | Loss:  tensor(17.6625, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  120  | Loss:  tensor(17.7069, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  130  | Loss:  tensor(17.7439, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  140  | Loss:  tensor(17.7733, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  150  | Loss:  tensor(17.7178, device='cuda:0')  | Accuracy:  tensor(0.0364, device='cuda:0')
# Epoch:  160  | Loss:  tensor(17.6935, device='cuda:0')  | Accuracy:  tensor(0.0412, device='cuda:0')
# Epoch:  170  | Loss:  tensor(17.5013, device='cuda:0')  | Accuracy:  tensor(0.0714, device='cuda:0')
# Epoch:  180  | Loss:  tensor(17.5262, device='cuda:0')  | Accuracy:  tensor(0.0814, device='cuda:0')
# Epoch:  190  | Loss:  tensor(17.5260, device='cuda:0')  | Accuracy:  tensor(0.0864, device='cuda:0')
# Epoch:  200  | Loss:  tensor(17.4378, device='cuda:0')  | Accuracy:  tensor(0.1178, device='cuda:0')
# Epoch:  210  | Loss:  tensor(17.1005, device='cuda:0')  | Accuracy:  tensor(0.1738, device='cuda:0')
# Epoch:  220  | Loss:  tensor(17.0078, device='cuda:0')  | Accuracy:  tensor(0.1899, device='cuda:0')
# Epoch:  230  | Loss:  tensor(16.7739, device='cuda:0')  | Accuracy:  tensor(0.2253, device='cuda:0')
# Epoch:  240  | Loss:  tensor(16.5650, device='cuda:0')  | Accuracy:  tensor(0.2584, device='cuda:0')
# Epoch:  250  | Loss:  tensor(16.0754, device='cuda:0')  | Accuracy:  tensor(0.3293, device='cuda:0')
# Epoch:  260  | Loss:  tensor(16.4359, device='cuda:0')  | Accuracy:  tensor(0.2818, device='cuda:0')
